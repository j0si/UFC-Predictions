# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Why do this step?
#
# - The data we scraped from the UFC website is raw data. Every row contains information about a fight that took place i.e. details like how many strikes were thrown in that fight and who won the fight.
# - To prepare the data for prediction, every row can contain only an accurate representation of what each fighter has done in fights up until that fight! No data that was recorded during the fight can be present in that row.
# - Our Target variable is Winner. The task has to be to predict the winner from the data available of each fighter up until the fight

# %% [markdown]
# ## Looking at the data

# %%
import pandas as pd
import numpy as np
import math

df = pd.read_csv('../data/raw_total_fight_data.csv', sep=';')
fighter_details = pd.read_csv('../data/raw_fighter_details.csv', index_col='fighter_name')

# %%
df.head()
# Out:
#               R_fighter            B_fighter  R_KD  B_KD R_SIG_STR.  \
# 0  Jack Della Maddalena          Randy Brown     1     0   14 of 31
# 1           Tyson Pedro   Modestas Bukauskas     0     0   45 of 81
# 2          Shannon Ross   Kleydson Rodrigues     0     1     1 of 4
# 3           Justin Tafa        Parker Porter     1     0    8 of 16
# 4          Josh Culibao  Melsik Baghdasaryan     0     0   16 of 45
#
#   B_SIG_STR. R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ...  \
# 0   11 of 39           45%           28%     18 of 35     11 of 39  ...
# 1  44 of 109           55%           40%     54 of 90    56 of 121  ...
# 2   14 of 22           25%           63%       1 of 4     16 of 24  ...
# 3    7 of 16           50%           43%      8 of 16      7 of 16  ...
# 4   26 of 44           35%           59%     16 of 45     26 of 44  ...
#
#   B_GROUND                win_by last_round last_round_time         Format  \
# 0   0 of 0            Submission          1            2:13  3 Rnd (5-5-5)
# 1   0 of 0  Decision - Unanimous          3            5:00  3 Rnd (5-5-5)
# 2   0 of 1                KO/TKO          1            0:59  3 Rnd (5-5-5)
# 3   0 of 0                KO/TKO          1            1:06  3 Rnd (5-5-5)
# 4   0 of 0            Submission          2            2:02  3 Rnd (5-5-5)
#
#           Referee               date                             location  \
# 0    Marc Goddard  February 11, 2023  Perth, Western Australia, Australia
# 1  Steve Perceval  February 11, 2023  Perth, Western Australia, Australia
# 2      Matt Wynne  February 11, 2023  Perth, Western Australia, Australia
# 3    Jason Herzog  February 11, 2023  Perth, Western Australia, Australia
# 4  Peter Hickmott  February 11, 2023  Perth, Western Australia, Australia
#
#                Fight_type                Winner
# 0       Welterweight Bout  Jack Della Maddalena
# 1  Light Heavyweight Bout    Modestas Bukauskas
# 2          Flyweight Bout    Kleydson Rodrigues
# 3        Heavyweight Bout           Justin Tafa
# 4      Featherweight Bout          Josh Culibao
#
# [5 rows x 41 columns]

# %%
df.T
# Out:
#                                                 0     \
# R_fighter                       Jack Della Maddalena
# B_fighter                                Randy Brown
# R_KD                                               1
# B_KD                                               0
# R_SIG_STR.                                  14 of 31
# B_SIG_STR.                                  11 of 39
# R_SIG_STR_pct                                    45%
# B_SIG_STR_pct                                    28%
# R_TOTAL_STR.                                18 of 35
# B_TOTAL_STR.                                11 of 39
# R_TD                                          0 of 0
# B_TD                                          0 of 0
# R_TD_pct                                         ---
# B_TD_pct                                         ---
# R_SUB_ATT                                          1
# B_SUB_ATT                                          0
# R_REV                                              0
# B_REV                                              0
# R_CTRL                                          0:15
# B_CTRL                                          0:00
# R_HEAD                                       9 of 23
# B_HEAD                                       6 of 33
# R_BODY                                        1 of 2
# B_BODY                                        2 of 3
# R_LEG                                         4 of 6
# B_LEG                                         3 of 3
# R_DISTANCE                                   5 of 18
# B_DISTANCE                                  11 of 39
# R_CLINCH                                      2 of 2
# B_CLINCH                                      0 of 0
# R_GROUND                                     7 of 11
# B_GROUND                                      0 of 0
# win_by                                    Submission
# last_round                                         1
# last_round_time                                 2:13
# Format                                 3 Rnd (5-5-5)
# Referee                                 Marc Goddard
# date                               February 11, 2023
# location         Perth, Western Australia, Australia
# Fight_type                         Welterweight Bout
# Winner                          Jack Della Maddalena
#
#                                                 1     \
# R_fighter                                Tyson Pedro
# B_fighter                         Modestas Bukauskas
# R_KD                                               0
# B_KD                                               0
# R_SIG_STR.                                  45 of 81
# B_SIG_STR.                                 44 of 109
# R_SIG_STR_pct                                    55%
# B_SIG_STR_pct                                    40%
# R_TOTAL_STR.                                54 of 90
# B_TOTAL_STR.                               56 of 121
# R_TD                                          2 of 3
# B_TD                                          0 of 0
# R_TD_pct                                         66%
# B_TD_pct                                         ---
# R_SUB_ATT                                          0
# B_SUB_ATT                                          0
# R_REV                                              0
# B_REV                                              0
# R_CTRL                                          3:01
# B_CTRL                                          0:57
# R_HEAD                                      18 of 45
# B_HEAD                                      25 of 88
# R_BODY                                      20 of 27
# B_BODY                                      12 of 13
# R_LEG                                         7 of 9
# B_LEG                                         7 of 8
# R_DISTANCE                                  39 of 74
# B_DISTANCE                                  34 of 95
# R_CLINCH                                      5 of 6
# B_CLINCH                                    10 of 14
# R_GROUND                                      1 of 1
# B_GROUND                                      0 of 0
# win_by                          Decision - Unanimous
# last_round                                         3
# last_round_time                                 5:00
# Format                                 3 Rnd (5-5-5)
# Referee                               Steve Perceval
# date                               February 11, 2023
# location         Perth, Western Australia, Australia
# Fight_type                    Light Heavyweight Bout
# Winner                            Modestas Bukauskas
#
#                                                 2     \
# R_fighter                               Shannon Ross
# B_fighter                         Kleydson Rodrigues
# R_KD                                               0
# B_KD                                               1
# R_SIG_STR.                                    1 of 4
# B_SIG_STR.                                  14 of 22
# R_SIG_STR_pct                                    25%
# B_SIG_STR_pct                                    63%
# R_TOTAL_STR.                                  1 of 4
# B_TOTAL_STR.                                16 of 24
# R_TD                                          0 of 0
# B_TD                                          0 of 0
# R_TD_pct                                         ---
# B_TD_pct                                         ---
# R_SUB_ATT                                          0
# B_SUB_ATT                                          0
# R_REV                                              0
# B_REV                                              0
# R_CTRL                                          0:00
# B_CTRL                                          0:00
# R_HEAD                                        0 of 1
# B_HEAD                                       8 of 16
# R_BODY                                        0 of 0
# B_BODY                                        3 of 3
# R_LEG                                         1 of 3
# B_LEG                                         3 of 3
# R_DISTANCE                                    1 of 4
# B_DISTANCE                                   9 of 14
# R_CLINCH                                      0 of 0
# B_CLINCH                                      5 of 7
# R_GROUND                                      0 of 0
# B_GROUND                                      0 of 1
# win_by                                        KO/TKO
# last_round                                         1
# last_round_time                                 0:59
# Format                                 3 Rnd (5-5-5)
# Referee                                   Matt Wynne
# date                               February 11, 2023
# location         Perth, Western Australia, Australia
# Fight_type                            Flyweight Bout
# Winner                            Kleydson Rodrigues
#
#                                                 3     \
# R_fighter                                Justin Tafa
# B_fighter                              Parker Porter
# R_KD                                               1
# B_KD                                               0
# R_SIG_STR.                                   8 of 16
# B_SIG_STR.                                   7 of 16
# R_SIG_STR_pct                                    50%
# B_SIG_STR_pct                                    43%
# R_TOTAL_STR.                                 8 of 16
# B_TOTAL_STR.                                 7 of 16
# R_TD                                          0 of 0
# B_TD                                          0 of 0
# R_TD_pct                                         ---
# B_TD_pct                                         ---
# R_SUB_ATT                                          0
# B_SUB_ATT                                          0
# R_REV                                              0
# B_REV                                              0
# R_CTRL                                          0:00
# B_CTRL                                          0:00
# R_HEAD                                       6 of 13
# B_HEAD                                       5 of 13
# R_BODY                                        2 of 3
# B_BODY                                        0 of 1
# R_LEG                                         0 of 0
# B_LEG                                         2 of 2
# R_DISTANCE                                   5 of 12
# B_DISTANCE                                   7 of 15
# R_CLINCH                                      3 of 4
# B_CLINCH                                      0 of 1
# R_GROUND                                      0 of 0
# B_GROUND                                      0 of 0
# win_by                                        KO/TKO
# last_round                                         1
# last_round_time                                 1:06
# Format                                 3 Rnd (5-5-5)
# Referee                                 Jason Herzog
# date                               February 11, 2023
# location         Perth, Western Australia, Australia
# Fight_type                          Heavyweight Bout
# Winner                                   Justin Tafa
#
#                                                 4     \
# R_fighter                               Josh Culibao
# B_fighter                        Melsik Baghdasaryan
# R_KD                                               0
# B_KD                                               0
# R_SIG_STR.                                  16 of 45
# B_SIG_STR.                                  26 of 44
# R_SIG_STR_pct                                    35%
# B_SIG_STR_pct                                    59%
# R_TOTAL_STR.                                16 of 45
# B_TOTAL_STR.                                26 of 44
# R_TD                                          0 of 0
# B_TD                                          0 of 0
# R_TD_pct                                         ---
# B_TD_pct                                         ---
# R_SUB_ATT                                          1
# B_SUB_ATT                                          0
# R_REV                                              0
# B_REV                                              0
# R_CTRL                                          0:14
# B_CTRL                                          0:00
# R_HEAD                                       3 of 24
# B_HEAD                                       6 of 19
# R_BODY                                        3 of 8
# B_BODY                                       8 of 10
# R_LEG                                       10 of 13
# B_LEG                                       12 of 15
# R_DISTANCE                                  15 of 43
# B_DISTANCE                                  24 of 41
# R_CLINCH                                      1 of 2
# B_CLINCH                                      2 of 3
# R_GROUND                                      0 of 0
# B_GROUND                                      0 of 0
# win_by                                    Submission
# last_round                                         2
# last_round_time                                 2:02
# Format                                 3 Rnd (5-5-5)
# Referee                               Peter Hickmott
# date                               February 11, 2023
# location         Perth, Western Australia, Australia
# Fight_type                        Featherweight Bout
# Winner                                  Josh Culibao
#
#                                                 5     \
# R_fighter                                Jimmy Crute
# B_fighter                           Alonzo Menifield
# R_KD                                               0
# B_KD                                               2
# R_SIG_STR.                                  31 of 62
# B_SIG_STR.                                  56 of 83
# R_SIG_STR_pct                                    50%
# B_SIG_STR_pct                                    67%
# R_TOTAL_STR.                               62 of 103
# B_TOTAL_STR.                               99 of 127
# R_TD                                         6 of 12
# B_TD                                          0 of 0
# R_TD_pct                                         50%
# B_TD_pct                                         ---
# R_SUB_ATT                                          3
# B_SUB_ATT                                          0
# R_REV                                              0
# B_REV                                              0
# R_CTRL                                          7:55
# B_CTRL                                          3:55
# R_HEAD                                      27 of 58
# B_HEAD                                      53 of 80
# R_BODY                                        2 of 2
# B_BODY                                        1 of 1
# R_LEG                                         2 of 2
# B_LEG                                         2 of 2
# R_DISTANCE                                  23 of 54
# B_DISTANCE                                  42 of 67
# R_CLINCH                                      5 of 5
# B_CLINCH                                      4 of 4
# R_GROUND                                      3 of 3
# B_GROUND                                    10 of 12
# win_by                           Decision - Majority
# last_round                                         3
# last_round_time                                 5:00
# Format                                 3 Rnd (5-5-5)
# Referee                                 Marc Goddard
# date                               February 11, 2023
# location         Perth, Western Australia, Australia
# Fight_type                    Light Heavyweight Bout
# Winner                                           NaN
#
#                                                 6     \
# R_fighter                            Islam Makhachev
# B_fighter                      Alexander Volkanovski
# R_KD                                               0
# B_KD                                               1
# R_SIG_STR.                                  57 of 95
# B_SIG_STR.                                 70 of 143
# R_SIG_STR_pct                                    60%
# B_SIG_STR_pct                                    48%
# R_TOTAL_STR.                               95 of 135
# B_TOTAL_STR.                              164 of 255
# R_TD                                          4 of 9
# B_TD                                          0 of 4
# R_TD_pct                                         44%
# B_TD_pct                                          0%
# R_SUB_ATT                                          0
# B_SUB_ATT                                          0
# R_REV                                              0
# B_REV                                              0
# R_CTRL                                          7:37
# B_CTRL                                          2:55
# R_HEAD                                      36 of 72
# B_HEAD                                      37 of 96
# R_BODY                                      18 of 20
# B_BODY                                      21 of 33
# R_LEG                                         3 of 3
# B_LEG                                       12 of 14
# R_DISTANCE                                  45 of 82
# B_DISTANCE                                 58 of 125
# R_CLINCH                                    12 of 13
# B_CLINCH                                     6 of 10
# R_GROUND                                      0 of 0
# B_GROUND                                      6 of 8
# win_by                          Decision - Unanimous
# last_round                                         5
# last_round_time                                 5:00
# Format                             5 Rnd (5-5-5-5-5)
# Referee                                 Marc Goddard
# date                               February 11, 2023
# location         Perth, Western Australia, Australia
# Fight_type                UFC Lightweight Title Bout
# Winner                               Islam Makhachev
#
#                                                  7     \
# R_fighter                              Yair Rodriguez
# B_fighter                                 Josh Emmett
# R_KD                                                0
# B_KD                                                0
# R_SIG_STR.                                  62 of 107
# B_SIG_STR.                                   22 of 52
# R_SIG_STR_pct                                     57%
# B_SIG_STR_pct                                     42%
# R_TOTAL_STR.                                98 of 143
# B_TOTAL_STR.                                 35 of 72
# R_TD                                           0 of 0
# B_TD                                           1 of 4
# R_TD_pct                                          ---
# B_TD_pct                                          25%
# R_SUB_ATT                                           1
# B_SUB_ATT                                           0
# R_REV                                               0
# B_REV                                               0
# R_CTRL                                           0:00
# B_CTRL                                           3:01
# R_HEAD                                       36 of 76
# B_HEAD                                       17 of 44
# R_BODY                                       18 of 22
# B_BODY                                         4 of 7
# R_LEG                                          8 of 9
# B_LEG                                          1 of 1
# R_DISTANCE                                   47 of 87
# B_DISTANCE                                   13 of 40
# R_CLINCH                                       7 of 9
# B_CLINCH                                       1 of 2
# R_GROUND                                      8 of 11
# B_GROUND                                      8 of 10
# win_by                                     Submission
# last_round                                          2
# last_round_time                                  4:19
# Format                              5 Rnd (5-5-5-5-5)
# Referee                                  Jason Herzog
# date                                February 11, 2023
# location          Perth, Western Australia, Australia
# Fight_type       UFC Interim Featherweight Title Bout
# Winner                                 Yair Rodriguez
#
#                                                 8     \
# R_fighter                                Shane Young
# B_fighter                               Blake Bilder
# R_KD                                               0
# B_KD                                               0
# R_SIG_STR.                                 80 of 196
# B_SIG_STR.                                111 of 190
# R_SIG_STR_pct                                    40%
# B_SIG_STR_pct                                    58%
# R_TOTAL_STR.                               81 of 197
# B_TOTAL_STR.                              126 of 206
# R_TD                                          0 of 3
# B_TD                                          1 of 7
# R_TD_pct                                          0%
# B_TD_pct                                         14%
# R_SUB_ATT                                          0
# B_SUB_ATT                                          0
# R_REV                                              0
# B_REV                                              0
# R_CTRL                                          0:03
# B_CTRL                                          1:43
# R_HEAD                                     42 of 151
# B_HEAD                                     62 of 134
# R_BODY                                      21 of 28
# B_BODY                                      11 of 17
# R_LEG                                       17 of 17
# B_LEG                                       38 of 39
# R_DISTANCE                                 79 of 194
# B_DISTANCE                                107 of 182
# R_CLINCH                                      1 of 2
# B_CLINCH                                      3 of 5
# R_GROUND                                      0 of 0
# B_GROUND                                      1 of 3
# win_by                          Decision - Unanimous
# last_round                                         3
# last_round_time                                 5:00
# Format                                 3 Rnd (5-5-5)
# Referee                               Peter Hickmott
# date                               February 11, 2023
# location         Perth, Western Australia, Australia
# Fight_type                        Featherweight Bout
# Winner                                  Blake Bilder
#
#                                                 9     ...  \
# R_fighter                           Loma Lookboonmee  ...
# B_fighter                                 Elise Reed  ...
# R_KD                                               0  ...
# B_KD                                               0  ...
# R_SIG_STR.                                  17 of 27  ...
# B_SIG_STR.                                  17 of 29  ...
# R_SIG_STR_pct                                    62%  ...
# B_SIG_STR_pct                                    58%  ...
# R_TOTAL_STR.                                22 of 34  ...
# B_TOTAL_STR.                                41 of 60  ...
# R_TD                                          2 of 3  ...
# B_TD                                          0 of 0  ...
# R_TD_pct                                         66%  ...
# B_TD_pct                                         ---  ...
# R_SUB_ATT                                          1  ...
# B_SUB_ATT                                          0  ...
# R_REV                                              0  ...
# B_REV                                              1  ...
# R_CTRL                                          0:36  ...
# B_CTRL                                          1:59  ...
# R_HEAD                                        5 of 8  ...
# B_HEAD                                      12 of 23  ...
# R_BODY                                        6 of 9  ...
# B_BODY                                        1 of 2  ...
# R_LEG                                        6 of 10  ...
# B_LEG                                         4 of 4  ...
# R_DISTANCE                                  12 of 20  ...
# B_DISTANCE                                   7 of 18  ...
# R_CLINCH                                      4 of 5  ...
# B_CLINCH                                      5 of 6  ...
# R_GROUND                                      1 of 2  ...
# B_GROUND                                      5 of 5  ...
# win_by                                    Submission  ...
# last_round                                         2  ...
# last_round_time                                 0:44  ...
# Format                                 3 Rnd (5-5-5)  ...
# Referee                               Steve Perceval  ...
# date                               February 11, 2023  ...
# location         Perth, Western Australia, Australia  ...
# Fight_type                  Women's Strawweight Bout  ...
# Winner                              Loma Lookboonmee  ...
#
#                                   6956                   6957  \
# R_fighter                Johnny Rhodes           Royce Gracie
# B_fighter                  Fred Ettish        Minoki Ichihara
# R_KD                                 1                      0
# B_KD                                 0                      0
# R_SIG_STR.                    13 of 29                 2 of 4
# B_SIG_STR.                      4 of 7                 3 of 7
# R_SIG_STR_pct                      44%                    50%
# B_SIG_STR_pct                      57%                    42%
# R_TOTAL_STR.                  21 of 38             110 of 114
# B_TOTAL_STR.                   7 of 11               12 of 16
# R_TD                            0 of 0                 1 of 1
# B_TD                            0 of 0                 0 of 0
# R_TD_pct                           ---                   100%
# B_TD_pct                           ---                    ---
# R_SUB_ATT                            1                      2
# B_SUB_ATT                            0                      0
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                        12 of 28                 0 of 0
# B_HEAD                          0 of 1                 3 of 6
# R_BODY                          0 of 0                 0 of 0
# B_BODY                          2 of 4                 0 of 0
# R_LEG                           1 of 1                 2 of 4
# B_LEG                           2 of 2                 0 of 1
# R_DISTANCE                      3 of 6                 2 of 4
# B_DISTANCE                      4 of 7                 0 of 2
# R_CLINCH                        1 of 2                 0 of 0
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                       9 of 21                 0 of 0
# B_GROUND                        0 of 0                 3 of 5
# win_by                      Submission             Submission
# last_round                           1                      1
# last_round_time                   3:07                   5:08
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Johnny Rhodes           Royce Gracie
#
#                                   6958                   6959  \
# R_fighter                Patrick Smith           Orlando Wiet
# B_fighter                 Scott Morris       Robert Lucarelli
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                    13 of 17                8 of 12
# B_SIG_STR.                      0 of 0                 2 of 6
# R_SIG_STR_pct                      76%                    66%
# B_SIG_STR_pct                      ---                    33%
# R_TOTAL_STR.                  19 of 25               11 of 15
# B_TOTAL_STR.                    0 of 0                 2 of 6
# R_TD                            0 of 0                 0 of 0
# B_TD                            0 of 1                 1 of 1
# R_TD_pct                           ---                    ---
# B_TD_pct                            0%                   100%
# R_SUB_ATT                            0                      0
# B_SUB_ATT                            0                      1
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                        12 of 16                7 of 11
# B_HEAD                          0 of 0                 1 of 2
# R_BODY                          1 of 1                 1 of 1
# B_BODY                          0 of 0                 0 of 1
# R_LEG                           0 of 0                 0 of 0
# B_LEG                           0 of 0                 1 of 3
# R_DISTANCE                      0 of 0                 1 of 3
# B_DISTANCE                      0 of 0                 2 of 6
# R_CLINCH                        1 of 1                 0 of 0
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                      12 of 16                 7 of 9
# B_GROUND                        0 of 0                 0 of 0
# win_by                          KO/TKO                 KO/TKO
# last_round                           1                      1
# last_round_time                   0:30                   2:50
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Patrick Smith           Orlando Wiet
#
#                                   6960                   6961  \
# R_fighter                Johnny Rhodes          Jason DeLucia
# B_fighter                David Levicki            Scott Baker
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                    11 of 17                 3 of 5
# B_SIG_STR.                      4 of 5                 0 of 2
# R_SIG_STR_pct                      64%                    60%
# B_SIG_STR_pct                      80%                     0%
# R_TOTAL_STR.                  74 of 86               20 of 25
# B_TOTAL_STR.                 95 of 102               14 of 23
# R_TD                            1 of 1                 0 of 1
# B_TD                            0 of 0                 1 of 1
# R_TD_pct                          100%                     0%
# B_TD_pct                           ---                   100%
# R_SUB_ATT                            0                      5
# B_SUB_ATT                            0                      0
# R_REV                                0                      4
# B_REV                                0                      2
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                         9 of 15                 1 of 2
# B_HEAD                          4 of 5                 0 of 2
# R_BODY                          1 of 1                 1 of 2
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           1 of 1                 1 of 1
# B_LEG                           0 of 0                 0 of 0
# R_DISTANCE                      1 of 1                 2 of 4
# B_DISTANCE                      1 of 2                 0 of 2
# R_CLINCH                        1 of 1                 0 of 0
# B_CLINCH                        2 of 2                 0 of 0
# R_GROUND                       9 of 15                 1 of 1
# B_GROUND                        1 of 1                 0 of 0
# win_by                          KO/TKO             Submission
# last_round                           1                      1
# last_round_time                  12:13                   6:41
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Johnny Rhodes          Jason DeLucia
#
#                                   6962                   6963  \
# R_fighter                Remco Pardoel          Frank Hamaker
# B_fighter           Alberta Cerra Leon        Thaddeus Luster
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      4 of 6                 2 of 3
# B_SIG_STR.                      1 of 3                 0 of 0
# R_SIG_STR_pct                      66%                    66%
# B_SIG_STR_pct                      33%                    ---
# R_TOTAL_STR.                  20 of 22               14 of 15
# B_TOTAL_STR.                   9 of 11                 0 of 0
# R_TD                            1 of 1                 1 of 1
# B_TD                            0 of 0                 0 of 1
# R_TD_pct                          100%                   100%
# B_TD_pct                           ---                     0%
# R_SUB_ATT                            1                      3
# B_SUB_ATT                            0                      0
# R_REV                                0                      1
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          4 of 5                 2 of 3
# B_HEAD                          1 of 3                 0 of 0
# R_BODY                          0 of 0                 0 of 0
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           0 of 1                 0 of 0
# B_LEG                           0 of 0                 0 of 0
# R_DISTANCE                      0 of 1                 1 of 1
# B_DISTANCE                      1 of 1                 0 of 0
# R_CLINCH                        0 of 0                 0 of 0
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                        4 of 5                 1 of 2
# B_GROUND                        0 of 2                 0 of 0
# win_by                      Submission             Submission
# last_round                           1                      1
# last_round_time                   9:51                   4:52
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Remco Pardoel          Frank Hamaker
#
#                                   6964                   6965
# R_fighter                 Scott Morris          Patrick Smith
# B_fighter               Sean Daugherty             Ray Wizard
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      1 of 1                 1 of 1
# B_SIG_STR.                      0 of 4                 1 of 1
# R_SIG_STR_pct                     100%                   100%
# B_SIG_STR_pct                       0%                   100%
# R_TOTAL_STR.                    2 of 2                 1 of 1
# B_TOTAL_STR.                    1 of 5                 2 of 2
# R_TD                            1 of 1                 0 of 1
# B_TD                            0 of 0                 0 of 0
# R_TD_pct                          100%                     0%
# B_TD_pct                           ---                    ---
# R_SUB_ATT                            1                      1
# B_SUB_ATT                            0                      0
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          1 of 1                 0 of 0
# B_HEAD                          0 of 2                 0 of 0
# R_BODY                          0 of 0                 1 of 1
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           0 of 0                 0 of 0
# B_LEG                           0 of 2                 1 of 1
# R_DISTANCE                      0 of 0                 0 of 0
# B_DISTANCE                      0 of 3                 1 of 1
# R_CLINCH                        1 of 1                 1 of 1
# B_CLINCH                        0 of 1                 0 of 0
# R_GROUND                        0 of 0                 0 of 0
# B_GROUND                        0 of 0                 0 of 0
# win_by                      Submission             Submission
# last_round                           1                      1
# last_round_time                   0:20                   0:58
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                    Scott Morris          Patrick Smith
#
# [41 rows x 6966 columns]

# %%
df.describe()
# Out:
#               R_KD         B_KD    R_SUB_ATT    B_SUB_ATT        R_REV  \
# count  6966.000000  6966.000000  6966.000000  6966.000000  6966.000000
# mean      0.248923     0.183175     0.461384     0.333190     0.136520
# std       0.524814     0.461943     0.903619     0.775585     0.428552
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     0.000000     0.000000
# max       5.000000     4.000000    10.000000     7.000000     6.000000
#
#              B_REV   last_round
# count  6966.000000  6966.000000
# mean      0.135515     2.333764
# std       0.419563     1.013973
# min       0.000000     1.000000
# 25%       0.000000     1.000000
# 50%       0.000000     3.000000
# 75%       0.000000     3.000000
# max       4.000000     5.000000

# %%
df.dtypes
# Out:
# R_fighter          object
# B_fighter          object
# R_KD                int64
# B_KD                int64
# R_SIG_STR.         object
# B_SIG_STR.         object
# R_SIG_STR_pct      object
# B_SIG_STR_pct      object
# R_TOTAL_STR.       object
# B_TOTAL_STR.       object
# R_TD               object
# B_TD               object
# R_TD_pct           object
# B_TD_pct           object
# R_SUB_ATT           int64
# B_SUB_ATT           int64
# R_REV               int64
# B_REV               int64
# R_CTRL             object
# B_CTRL             object
# R_HEAD             object
# B_HEAD             object
# R_BODY             object
# B_BODY             object
# R_LEG              object
# B_LEG              object
# R_DISTANCE         object
# B_DISTANCE         object
# R_CLINCH           object
# B_CLINCH           object
# R_GROUND           object
# B_GROUND           object
# win_by             object
# last_round          int64
# last_round_time    object
# Format             object
# Referee            object
# date               object
# location           object
# Fight_type         object
# Winner             object
# dtype: object

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR.', 'B_SIG_STR.',
#        'R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
#        'R_TD', 'B_TD', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'R_CTRL', 'B_CTRL', 'R_HEAD', 'B_HEAD', 'R_BODY',
#        'B_BODY', 'R_LEG', 'B_LEG', 'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH',
#        'B_CLINCH', 'R_GROUND', 'B_GROUND', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner'],
#       dtype='object')

# %% [markdown]
# ### Column definitions:
#
# - `R_` and `B_` prefix signifies red and blue corner fighter stats respectively
# - `KD` is number of knockdowns
# - `SIG_STR` is no. of significant strikes 'landed of attempted'
# - `SIG_STR_pct` is significant strikes percentage
# - `TOTAL_STR` is total strikes 'landed of attempted'
# - `TD` is no. of takedowns
# - `TD_pct` is takedown percentages
# - `SUB_ATT` is no. of submission attempts
# - `PASS` is no. times the guard was passed?
# - `REV` is the no. of reversals
# - `CTRL` is the time spent with ground control
# - `HEAD` is no. of significant strinks to the head 'landed of attempted'
# - `BODY` is no. of significant strikes to the body 'landed of attempted'
# - `CLINCH` is no. of significant strikes in the clinch 'landed of attempted'
# - `GROUND` is no. of significant strikes on the ground 'landed of attempted'
# - `win_by` is method of win
# - `last_round` is last round of the fight (ex. if it was a KO in 1st, then this will be 1)
# - `last_round_time` is when the fight ended in the last round
# - `Format` is the format of the fight (3 rounds, 5 rounds etc.)
# - `Referee` is the name of the Ref
# - `date` is the date of the fight
# - `location` is the location in which the event took place
# - `Fight_type` is which weight class and whether it's a title bout or not
# - `Winner` is the winner of the fight
#
# #### Per fighter career wide stats
# - `SLpM` - Significant Strikes Landed per Minute
# - `Str_Acc.` - Significant Striking Accuracy
# - `SApM` - Significant Strikes Absorbed per Minute
# - `Str_Def` - Significant Strike Defence (the % of opponents strikes that did not land)
# - `TD_Avg` - Average Takedowns Landed per 15 minutes
# - `TD_Acc` - Takedown Accuracy
# - `TD_Def` - Takedown Defense (the % of opponents TD attempts that did not land)
# - `Sub_Avg` - Average Submissions Attempted per 15 minutes

# %% [markdown]
# ## Todo:
#
# - Separate `landed of attempted` to separate columns
#
# - Convert `Fight_type` into two separate columns, `weight_class` and `Title_fight` (True or False)
#
# - Convert `last_round_time` to `total_time_fought` by using `last_round` and `Format`
#
# - Convert `CTRL` to `time_in_CTRL`
#
# - Convert percentages to fractions
#
# - Since the data is a description of each fight, we have to convert it into a format that shows the compilation data of each fighter up until that fight. This means every row will look a lot different than it looks now.
#
# - Create `current_win_streak`, `current_lose_streak`, `longest_win_streak`, `wins`, `losses`, `draw`
#
# - Create fighter `height`, `reach`, `weight`, `age`

# %%
fighter_details.drop(
    columns=["SLpM",
            "Str_Acc",
            "SApM",
            "Str_Def",
            "TD_Avg",
            "TD_Acc",
            "TD_Def",
            "Sub_Avg",
        ], inplace=True)

# %% [markdown]
# ### Splitting landed of attempted to different columns

# %%
columns = ['R_SIG_STR.', 'B_SIG_STR.', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
       'R_TD', 'B_TD', 'R_HEAD', 'B_HEAD', 'R_BODY','B_BODY', 'R_LEG', 'B_LEG', 
        'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH','B_CLINCH', 'R_GROUND', 'B_GROUND']

for column in columns:
    print(f"{column} data type is: {df[column].dtype}")
# Out:
# R_SIG_STR. data type is: object
# B_SIG_STR. data type is: object
# R_TOTAL_STR. data type is: object
# B_TOTAL_STR. data type is: object
# R_TD data type is: object
# B_TD data type is: object
# R_HEAD data type is: object
# B_HEAD data type is: object
# R_BODY data type is: object
# B_BODY data type is: object
# R_LEG data type is: object
# B_LEG data type is: object
# R_DISTANCE data type is: object
# B_DISTANCE data type is: object
# R_CLINCH data type is: object
# B_CLINCH data type is: object
# R_GROUND data type is: object
# B_GROUND data type is: object

# %%
attempt_suffix = '_att'
landed_suffix = '_landed'

for column in columns:
    df[column+attempt_suffix] = df[column].apply(lambda X: int(X.split('of')[1]))
    df[column+landed_suffix] = df[column].apply(lambda X: int(X.split('of')[0]))
    
df.drop(columns, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'R_CTRL', 'B_CTRL', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner', 'R_SIG_STR._att', 'R_SIG_STR._landed',
#        'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
#        'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
#        'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
#        'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
#        'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
#        'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
#        'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
#        'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
#        'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed'],
#       dtype='object')

# %% [markdown]
# ### Replacing Winner NaNs as Draw

# %%
for column in df.columns:
    if df[column].isnull().sum() != 0:
        print(f"NaN values in {column} = {df[column].isnull().sum()}")
# Out:
# NaN values in Referee = 32
# NaN values in Winner = 125

# %% [markdown]
# * 83 missing values in winner and 23 missing values in Referee

# %%
df[df['Winner'].isnull()]['win_by'].value_counts()
# Out:
# Overturned              50
# Decision - Majority     30
# Could Not Continue      20
# Decision - Split        16
# Decision - Unanimous     6
# Other                    3
# Name: win_by, dtype: int64

# %% [markdown]
# * Here, Overturned means due to drug test being positive and Could not Continue means there was an illegal blow which was not enough to be disqualified but the fighter could not continue.
# * The rest are different forms of draw
#
# * Replacing all of these with draw

# %%
df['Winner'].fillna('Draw', inplace=True)

# %% [markdown]
# ### Converting percentages to fractions

# %%
pct_columns = ['R_SIG_STR_pct','B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct']

def pct_to_frac(X):
    if X != '---':
        return float(X.replace('%', ''))/100
    else:
        # if '---' means it's taking pct of `0 of 0`. 
        # Taking a call here to consider 0 landed of 0 attempted as 0 percentage
        return 0

for column in pct_columns:
    df[column] = df[column].apply(pct_to_frac)

# %%
df.T
# Out:
#                                                     0     \
# R_fighter                           Jack Della Maddalena
# B_fighter                                    Randy Brown
# R_KD                                                   1
# B_KD                                                   0
# R_SIG_STR_pct                                       0.45
# B_SIG_STR_pct                                       0.28
# R_TD_pct                                               0
# B_TD_pct                                               0
# R_SUB_ATT                                              1
# B_SUB_ATT                                              0
# R_REV                                                  0
# B_REV                                                  0
# R_CTRL                                              0:15
# B_CTRL                                              0:00
# win_by                                        Submission
# last_round                                             1
# last_round_time                                     2:13
# Format                                     3 Rnd (5-5-5)
# Referee                                     Marc Goddard
# date                                   February 11, 2023
# location             Perth, Western Australia, Australia
# Fight_type                             Welterweight Bout
# Winner                              Jack Della Maddalena
# R_SIG_STR._att                                        31
# R_SIG_STR._landed                                     14
# B_SIG_STR._att                                        39
# B_SIG_STR._landed                                     11
# R_TOTAL_STR._att                                      35
# R_TOTAL_STR._landed                                   18
# B_TOTAL_STR._att                                      39
# B_TOTAL_STR._landed                                   11
# R_TD_att                                               0
# R_TD_landed                                            0
# B_TD_att                                               0
# B_TD_landed                                            0
# R_HEAD_att                                            23
# R_HEAD_landed                                          9
# B_HEAD_att                                            33
# B_HEAD_landed                                          6
# R_BODY_att                                             2
# R_BODY_landed                                          1
# B_BODY_att                                             3
# B_BODY_landed                                          2
# R_LEG_att                                              6
# R_LEG_landed                                           4
# B_LEG_att                                              3
# B_LEG_landed                                           3
# R_DISTANCE_att                                        18
# R_DISTANCE_landed                                      5
# B_DISTANCE_att                                        39
# B_DISTANCE_landed                                     11
# R_CLINCH_att                                           2
# R_CLINCH_landed                                        2
# B_CLINCH_att                                           0
# B_CLINCH_landed                                        0
# R_GROUND_att                                          11
# R_GROUND_landed                                        7
# B_GROUND_att                                           0
# B_GROUND_landed                                        0
#
#                                                     1     \
# R_fighter                                    Tyson Pedro
# B_fighter                             Modestas Bukauskas
# R_KD                                                   0
# B_KD                                                   0
# R_SIG_STR_pct                                       0.55
# B_SIG_STR_pct                                        0.4
# R_TD_pct                                            0.66
# B_TD_pct                                               0
# R_SUB_ATT                                              0
# B_SUB_ATT                                              0
# R_REV                                                  0
# B_REV                                                  0
# R_CTRL                                              3:01
# B_CTRL                                              0:57
# win_by                              Decision - Unanimous
# last_round                                             3
# last_round_time                                     5:00
# Format                                     3 Rnd (5-5-5)
# Referee                                   Steve Perceval
# date                                   February 11, 2023
# location             Perth, Western Australia, Australia
# Fight_type                        Light Heavyweight Bout
# Winner                                Modestas Bukauskas
# R_SIG_STR._att                                        81
# R_SIG_STR._landed                                     45
# B_SIG_STR._att                                       109
# B_SIG_STR._landed                                     44
# R_TOTAL_STR._att                                      90
# R_TOTAL_STR._landed                                   54
# B_TOTAL_STR._att                                     121
# B_TOTAL_STR._landed                                   56
# R_TD_att                                               3
# R_TD_landed                                            2
# B_TD_att                                               0
# B_TD_landed                                            0
# R_HEAD_att                                            45
# R_HEAD_landed                                         18
# B_HEAD_att                                            88
# B_HEAD_landed                                         25
# R_BODY_att                                            27
# R_BODY_landed                                         20
# B_BODY_att                                            13
# B_BODY_landed                                         12
# R_LEG_att                                              9
# R_LEG_landed                                           7
# B_LEG_att                                              8
# B_LEG_landed                                           7
# R_DISTANCE_att                                        74
# R_DISTANCE_landed                                     39
# B_DISTANCE_att                                        95
# B_DISTANCE_landed                                     34
# R_CLINCH_att                                           6
# R_CLINCH_landed                                        5
# B_CLINCH_att                                          14
# B_CLINCH_landed                                       10
# R_GROUND_att                                           1
# R_GROUND_landed                                        1
# B_GROUND_att                                           0
# B_GROUND_landed                                        0
#
#                                                     2     \
# R_fighter                                   Shannon Ross
# B_fighter                             Kleydson Rodrigues
# R_KD                                                   0
# B_KD                                                   1
# R_SIG_STR_pct                                       0.25
# B_SIG_STR_pct                                       0.63
# R_TD_pct                                               0
# B_TD_pct                                               0
# R_SUB_ATT                                              0
# B_SUB_ATT                                              0
# R_REV                                                  0
# B_REV                                                  0
# R_CTRL                                              0:00
# B_CTRL                                              0:00
# win_by                                            KO/TKO
# last_round                                             1
# last_round_time                                     0:59
# Format                                     3 Rnd (5-5-5)
# Referee                                       Matt Wynne
# date                                   February 11, 2023
# location             Perth, Western Australia, Australia
# Fight_type                                Flyweight Bout
# Winner                                Kleydson Rodrigues
# R_SIG_STR._att                                         4
# R_SIG_STR._landed                                      1
# B_SIG_STR._att                                        22
# B_SIG_STR._landed                                     14
# R_TOTAL_STR._att                                       4
# R_TOTAL_STR._landed                                    1
# B_TOTAL_STR._att                                      24
# B_TOTAL_STR._landed                                   16
# R_TD_att                                               0
# R_TD_landed                                            0
# B_TD_att                                               0
# B_TD_landed                                            0
# R_HEAD_att                                             1
# R_HEAD_landed                                          0
# B_HEAD_att                                            16
# B_HEAD_landed                                          8
# R_BODY_att                                             0
# R_BODY_landed                                          0
# B_BODY_att                                             3
# B_BODY_landed                                          3
# R_LEG_att                                              3
# R_LEG_landed                                           1
# B_LEG_att                                              3
# B_LEG_landed                                           3
# R_DISTANCE_att                                         4
# R_DISTANCE_landed                                      1
# B_DISTANCE_att                                        14
# B_DISTANCE_landed                                      9
# R_CLINCH_att                                           0
# R_CLINCH_landed                                        0
# B_CLINCH_att                                           7
# B_CLINCH_landed                                        5
# R_GROUND_att                                           0
# R_GROUND_landed                                        0
# B_GROUND_att                                           1
# B_GROUND_landed                                        0
#
#                                                     3     \
# R_fighter                                    Justin Tafa
# B_fighter                                  Parker Porter
# R_KD                                                   1
# B_KD                                                   0
# R_SIG_STR_pct                                        0.5
# B_SIG_STR_pct                                       0.43
# R_TD_pct                                               0
# B_TD_pct                                               0
# R_SUB_ATT                                              0
# B_SUB_ATT                                              0
# R_REV                                                  0
# B_REV                                                  0
# R_CTRL                                              0:00
# B_CTRL                                              0:00
# win_by                                            KO/TKO
# last_round                                             1
# last_round_time                                     1:06
# Format                                     3 Rnd (5-5-5)
# Referee                                     Jason Herzog
# date                                   February 11, 2023
# location             Perth, Western Australia, Australia
# Fight_type                              Heavyweight Bout
# Winner                                       Justin Tafa
# R_SIG_STR._att                                        16
# R_SIG_STR._landed                                      8
# B_SIG_STR._att                                        16
# B_SIG_STR._landed                                      7
# R_TOTAL_STR._att                                      16
# R_TOTAL_STR._landed                                    8
# B_TOTAL_STR._att                                      16
# B_TOTAL_STR._landed                                    7
# R_TD_att                                               0
# R_TD_landed                                            0
# B_TD_att                                               0
# B_TD_landed                                            0
# R_HEAD_att                                            13
# R_HEAD_landed                                          6
# B_HEAD_att                                            13
# B_HEAD_landed                                          5
# R_BODY_att                                             3
# R_BODY_landed                                          2
# B_BODY_att                                             1
# B_BODY_landed                                          0
# R_LEG_att                                              0
# R_LEG_landed                                           0
# B_LEG_att                                              2
# B_LEG_landed                                           2
# R_DISTANCE_att                                        12
# R_DISTANCE_landed                                      5
# B_DISTANCE_att                                        15
# B_DISTANCE_landed                                      7
# R_CLINCH_att                                           4
# R_CLINCH_landed                                        3
# B_CLINCH_att                                           1
# B_CLINCH_landed                                        0
# R_GROUND_att                                           0
# R_GROUND_landed                                        0
# B_GROUND_att                                           0
# B_GROUND_landed                                        0
#
#                                                     4     \
# R_fighter                                   Josh Culibao
# B_fighter                            Melsik Baghdasaryan
# R_KD                                                   0
# B_KD                                                   0
# R_SIG_STR_pct                                       0.35
# B_SIG_STR_pct                                       0.59
# R_TD_pct                                               0
# B_TD_pct                                               0
# R_SUB_ATT                                              1
# B_SUB_ATT                                              0
# R_REV                                                  0
# B_REV                                                  0
# R_CTRL                                              0:14
# B_CTRL                                              0:00
# win_by                                        Submission
# last_round                                             2
# last_round_time                                     2:02
# Format                                     3 Rnd (5-5-5)
# Referee                                   Peter Hickmott
# date                                   February 11, 2023
# location             Perth, Western Australia, Australia
# Fight_type                            Featherweight Bout
# Winner                                      Josh Culibao
# R_SIG_STR._att                                        45
# R_SIG_STR._landed                                     16
# B_SIG_STR._att                                        44
# B_SIG_STR._landed                                     26
# R_TOTAL_STR._att                                      45
# R_TOTAL_STR._landed                                   16
# B_TOTAL_STR._att                                      44
# B_TOTAL_STR._landed                                   26
# R_TD_att                                               0
# R_TD_landed                                            0
# B_TD_att                                               0
# B_TD_landed                                            0
# R_HEAD_att                                            24
# R_HEAD_landed                                          3
# B_HEAD_att                                            19
# B_HEAD_landed                                          6
# R_BODY_att                                             8
# R_BODY_landed                                          3
# B_BODY_att                                            10
# B_BODY_landed                                          8
# R_LEG_att                                             13
# R_LEG_landed                                          10
# B_LEG_att                                             15
# B_LEG_landed                                          12
# R_DISTANCE_att                                        43
# R_DISTANCE_landed                                     15
# B_DISTANCE_att                                        41
# B_DISTANCE_landed                                     24
# R_CLINCH_att                                           2
# R_CLINCH_landed                                        1
# B_CLINCH_att                                           3
# B_CLINCH_landed                                        2
# R_GROUND_att                                           0
# R_GROUND_landed                                        0
# B_GROUND_att                                           0
# B_GROUND_landed                                        0
#
#                                                     5     \
# R_fighter                                    Jimmy Crute
# B_fighter                               Alonzo Menifield
# R_KD                                                   0
# B_KD                                                   2
# R_SIG_STR_pct                                        0.5
# B_SIG_STR_pct                                       0.67
# R_TD_pct                                             0.5
# B_TD_pct                                               0
# R_SUB_ATT                                              3
# B_SUB_ATT                                              0
# R_REV                                                  0
# B_REV                                                  0
# R_CTRL                                              7:55
# B_CTRL                                              3:55
# win_by                               Decision - Majority
# last_round                                             3
# last_round_time                                     5:00
# Format                                     3 Rnd (5-5-5)
# Referee                                     Marc Goddard
# date                                   February 11, 2023
# location             Perth, Western Australia, Australia
# Fight_type                        Light Heavyweight Bout
# Winner                                              Draw
# R_SIG_STR._att                                        62
# R_SIG_STR._landed                                     31
# B_SIG_STR._att                                        83
# B_SIG_STR._landed                                     56
# R_TOTAL_STR._att                                     103
# R_TOTAL_STR._landed                                   62
# B_TOTAL_STR._att                                     127
# B_TOTAL_STR._landed                                   99
# R_TD_att                                              12
# R_TD_landed                                            6
# B_TD_att                                               0
# B_TD_landed                                            0
# R_HEAD_att                                            58
# R_HEAD_landed                                         27
# B_HEAD_att                                            80
# B_HEAD_landed                                         53
# R_BODY_att                                             2
# R_BODY_landed                                          2
# B_BODY_att                                             1
# B_BODY_landed                                          1
# R_LEG_att                                              2
# R_LEG_landed                                           2
# B_LEG_att                                              2
# B_LEG_landed                                           2
# R_DISTANCE_att                                        54
# R_DISTANCE_landed                                     23
# B_DISTANCE_att                                        67
# B_DISTANCE_landed                                     42
# R_CLINCH_att                                           5
# R_CLINCH_landed                                        5
# B_CLINCH_att                                           4
# B_CLINCH_landed                                        4
# R_GROUND_att                                           3
# R_GROUND_landed                                        3
# B_GROUND_att                                          12
# B_GROUND_landed                                       10
#
#                                                     6     \
# R_fighter                                Islam Makhachev
# B_fighter                          Alexander Volkanovski
# R_KD                                                   0
# B_KD                                                   1
# R_SIG_STR_pct                                        0.6
# B_SIG_STR_pct                                       0.48
# R_TD_pct                                            0.44
# B_TD_pct                                               0
# R_SUB_ATT                                              0
# B_SUB_ATT                                              0
# R_REV                                                  0
# B_REV                                                  0
# R_CTRL                                              7:37
# B_CTRL                                              2:55
# win_by                              Decision - Unanimous
# last_round                                             5
# last_round_time                                     5:00
# Format                                 5 Rnd (5-5-5-5-5)
# Referee                                     Marc Goddard
# date                                   February 11, 2023
# location             Perth, Western Australia, Australia
# Fight_type                    UFC Lightweight Title Bout
# Winner                                   Islam Makhachev
# R_SIG_STR._att                                        95
# R_SIG_STR._landed                                     57
# B_SIG_STR._att                                       143
# B_SIG_STR._landed                                     70
# R_TOTAL_STR._att                                     135
# R_TOTAL_STR._landed                                   95
# B_TOTAL_STR._att                                     255
# B_TOTAL_STR._landed                                  164
# R_TD_att                                               9
# R_TD_landed                                            4
# B_TD_att                                               4
# B_TD_landed                                            0
# R_HEAD_att                                            72
# R_HEAD_landed                                         36
# B_HEAD_att                                            96
# B_HEAD_landed                                         37
# R_BODY_att                                            20
# R_BODY_landed                                         18
# B_BODY_att                                            33
# B_BODY_landed                                         21
# R_LEG_att                                              3
# R_LEG_landed                                           3
# B_LEG_att                                             14
# B_LEG_landed                                          12
# R_DISTANCE_att                                        82
# R_DISTANCE_landed                                     45
# B_DISTANCE_att                                       125
# B_DISTANCE_landed                                     58
# R_CLINCH_att                                          13
# R_CLINCH_landed                                       12
# B_CLINCH_att                                          10
# B_CLINCH_landed                                        6
# R_GROUND_att                                           0
# R_GROUND_landed                                        0
# B_GROUND_att                                           8
# B_GROUND_landed                                        6
#
#                                                      7     \
# R_fighter                                  Yair Rodriguez
# B_fighter                                     Josh Emmett
# R_KD                                                    0
# B_KD                                                    0
# R_SIG_STR_pct                                        0.57
# B_SIG_STR_pct                                        0.42
# R_TD_pct                                                0
# B_TD_pct                                             0.25
# R_SUB_ATT                                               1
# B_SUB_ATT                                               0
# R_REV                                                   0
# B_REV                                                   0
# R_CTRL                                               0:00
# B_CTRL                                               3:01
# win_by                                         Submission
# last_round                                              2
# last_round_time                                      4:19
# Format                                  5 Rnd (5-5-5-5-5)
# Referee                                      Jason Herzog
# date                                    February 11, 2023
# location              Perth, Western Australia, Australia
# Fight_type           UFC Interim Featherweight Title Bout
# Winner                                     Yair Rodriguez
# R_SIG_STR._att                                        107
# R_SIG_STR._landed                                      62
# B_SIG_STR._att                                         52
# B_SIG_STR._landed                                      22
# R_TOTAL_STR._att                                      143
# R_TOTAL_STR._landed                                    98
# B_TOTAL_STR._att                                       72
# B_TOTAL_STR._landed                                    35
# R_TD_att                                                0
# R_TD_landed                                             0
# B_TD_att                                                4
# B_TD_landed                                             1
# R_HEAD_att                                             76
# R_HEAD_landed                                          36
# B_HEAD_att                                             44
# B_HEAD_landed                                          17
# R_BODY_att                                             22
# R_BODY_landed                                          18
# B_BODY_att                                              7
# B_BODY_landed                                           4
# R_LEG_att                                               9
# R_LEG_landed                                            8
# B_LEG_att                                               1
# B_LEG_landed                                            1
# R_DISTANCE_att                                         87
# R_DISTANCE_landed                                      47
# B_DISTANCE_att                                         40
# B_DISTANCE_landed                                      13
# R_CLINCH_att                                            9
# R_CLINCH_landed                                         7
# B_CLINCH_att                                            2
# B_CLINCH_landed                                         1
# R_GROUND_att                                           11
# R_GROUND_landed                                         8
# B_GROUND_att                                           10
# B_GROUND_landed                                         8
#
#                                                     8     \
# R_fighter                                    Shane Young
# B_fighter                                   Blake Bilder
# R_KD                                                   0
# B_KD                                                   0
# R_SIG_STR_pct                                        0.4
# B_SIG_STR_pct                                       0.58
# R_TD_pct                                               0
# B_TD_pct                                            0.14
# R_SUB_ATT                                              0
# B_SUB_ATT                                              0
# R_REV                                                  0
# B_REV                                                  0
# R_CTRL                                              0:03
# B_CTRL                                              1:43
# win_by                              Decision - Unanimous
# last_round                                             3
# last_round_time                                     5:00
# Format                                     3 Rnd (5-5-5)
# Referee                                   Peter Hickmott
# date                                   February 11, 2023
# location             Perth, Western Australia, Australia
# Fight_type                            Featherweight Bout
# Winner                                      Blake Bilder
# R_SIG_STR._att                                       196
# R_SIG_STR._landed                                     80
# B_SIG_STR._att                                       190
# B_SIG_STR._landed                                    111
# R_TOTAL_STR._att                                     197
# R_TOTAL_STR._landed                                   81
# B_TOTAL_STR._att                                     206
# B_TOTAL_STR._landed                                  126
# R_TD_att                                               3
# R_TD_landed                                            0
# B_TD_att                                               7
# B_TD_landed                                            1
# R_HEAD_att                                           151
# R_HEAD_landed                                         42
# B_HEAD_att                                           134
# B_HEAD_landed                                         62
# R_BODY_att                                            28
# R_BODY_landed                                         21
# B_BODY_att                                            17
# B_BODY_landed                                         11
# R_LEG_att                                             17
# R_LEG_landed                                          17
# B_LEG_att                                             39
# B_LEG_landed                                          38
# R_DISTANCE_att                                       194
# R_DISTANCE_landed                                     79
# B_DISTANCE_att                                       182
# B_DISTANCE_landed                                    107
# R_CLINCH_att                                           2
# R_CLINCH_landed                                        1
# B_CLINCH_att                                           5
# B_CLINCH_landed                                        3
# R_GROUND_att                                           0
# R_GROUND_landed                                        0
# B_GROUND_att                                           3
# B_GROUND_landed                                        1
#
#                                                     9     ...  \
# R_fighter                               Loma Lookboonmee  ...
# B_fighter                                     Elise Reed  ...
# R_KD                                                   0  ...
# B_KD                                                   0  ...
# R_SIG_STR_pct                                       0.62  ...
# B_SIG_STR_pct                                       0.58  ...
# R_TD_pct                                            0.66  ...
# B_TD_pct                                               0  ...
# R_SUB_ATT                                              1  ...
# B_SUB_ATT                                              0  ...
# R_REV                                                  0  ...
# B_REV                                                  1  ...
# R_CTRL                                              0:36  ...
# B_CTRL                                              1:59  ...
# win_by                                        Submission  ...
# last_round                                             2  ...
# last_round_time                                     0:44  ...
# Format                                     3 Rnd (5-5-5)  ...
# Referee                                   Steve Perceval  ...
# date                                   February 11, 2023  ...
# location             Perth, Western Australia, Australia  ...
# Fight_type                      Women's Strawweight Bout  ...
# Winner                                  Loma Lookboonmee  ...
# R_SIG_STR._att                                        27  ...
# R_SIG_STR._landed                                     17  ...
# B_SIG_STR._att                                        29  ...
# B_SIG_STR._landed                                     17  ...
# R_TOTAL_STR._att                                      34  ...
# R_TOTAL_STR._landed                                   22  ...
# B_TOTAL_STR._att                                      60  ...
# B_TOTAL_STR._landed                                   41  ...
# R_TD_att                                               3  ...
# R_TD_landed                                            2  ...
# B_TD_att                                               0  ...
# B_TD_landed                                            0  ...
# R_HEAD_att                                             8  ...
# R_HEAD_landed                                          5  ...
# B_HEAD_att                                            23  ...
# B_HEAD_landed                                         12  ...
# R_BODY_att                                             9  ...
# R_BODY_landed                                          6  ...
# B_BODY_att                                             2  ...
# B_BODY_landed                                          1  ...
# R_LEG_att                                             10  ...
# R_LEG_landed                                           6  ...
# B_LEG_att                                              4  ...
# B_LEG_landed                                           4  ...
# R_DISTANCE_att                                        20  ...
# R_DISTANCE_landed                                     12  ...
# B_DISTANCE_att                                        18  ...
# B_DISTANCE_landed                                      7  ...
# R_CLINCH_att                                           5  ...
# R_CLINCH_landed                                        4  ...
# B_CLINCH_att                                           6  ...
# B_CLINCH_landed                                        5  ...
# R_GROUND_att                                           2  ...
# R_GROUND_landed                                        1  ...
# B_GROUND_att                                           5  ...
# B_GROUND_landed                                        5  ...
#
#                                       6956                   6957  \
# R_fighter                    Johnny Rhodes           Royce Gracie
# B_fighter                      Fred Ettish        Minoki Ichihara
# R_KD                                     1                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.44                    0.5
# B_SIG_STR_pct                         0.57                   0.42
# R_TD_pct                                 0                      1
# B_TD_pct                                 0                      0
# R_SUB_ATT                                1                      2
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       3:07                   5:08
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Johnny Rhodes           Royce Gracie
# R_SIG_STR._att                          29                      4
# R_SIG_STR._landed                       13                      2
# B_SIG_STR._att                           7                      7
# B_SIG_STR._landed                        4                      3
# R_TOTAL_STR._att                        38                    114
# R_TOTAL_STR._landed                     21                    110
# B_TOTAL_STR._att                        11                     16
# B_TOTAL_STR._landed                      7                     12
# R_TD_att                                 0                      1
# R_TD_landed                              0                      1
# B_TD_att                                 0                      0
# B_TD_landed                              0                      0
# R_HEAD_att                              28                      0
# R_HEAD_landed                           12                      0
# B_HEAD_att                               1                      6
# B_HEAD_landed                            0                      3
# R_BODY_att                               0                      0
# R_BODY_landed                            0                      0
# B_BODY_att                               4                      0
# B_BODY_landed                            2                      0
# R_LEG_att                                1                      4
# R_LEG_landed                             1                      2
# B_LEG_att                                2                      1
# B_LEG_landed                             2                      0
# R_DISTANCE_att                           6                      4
# R_DISTANCE_landed                        3                      2
# B_DISTANCE_att                           7                      2
# B_DISTANCE_landed                        4                      0
# R_CLINCH_att                             2                      0
# R_CLINCH_landed                          1                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                            21                      0
# R_GROUND_landed                          9                      0
# B_GROUND_att                             0                      5
# B_GROUND_landed                          0                      3
#
#                                       6958                   6959  \
# R_fighter                    Patrick Smith           Orlando Wiet
# B_fighter                     Scott Morris       Robert Lucarelli
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.76                   0.66
# B_SIG_STR_pct                            0                   0.33
# R_TD_pct                                 0                      0
# B_TD_pct                                 0                      1
# R_SUB_ATT                                0                      0
# B_SUB_ATT                                0                      1
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                              KO/TKO                 KO/TKO
# last_round                               1                      1
# last_round_time                       0:30                   2:50
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Patrick Smith           Orlando Wiet
# R_SIG_STR._att                          17                     12
# R_SIG_STR._landed                       13                      8
# B_SIG_STR._att                           0                      6
# B_SIG_STR._landed                        0                      2
# R_TOTAL_STR._att                        25                     15
# R_TOTAL_STR._landed                     19                     11
# B_TOTAL_STR._att                         0                      6
# B_TOTAL_STR._landed                      0                      2
# R_TD_att                                 0                      0
# R_TD_landed                              0                      0
# B_TD_att                                 1                      1
# B_TD_landed                              0                      1
# R_HEAD_att                              16                     11
# R_HEAD_landed                           12                      7
# B_HEAD_att                               0                      2
# B_HEAD_landed                            0                      1
# R_BODY_att                               1                      1
# R_BODY_landed                            1                      1
# B_BODY_att                               0                      1
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                0                      3
# B_LEG_landed                             0                      1
# R_DISTANCE_att                           0                      3
# R_DISTANCE_landed                        0                      1
# B_DISTANCE_att                           0                      6
# B_DISTANCE_landed                        0                      2
# R_CLINCH_att                             1                      0
# R_CLINCH_landed                          1                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                            16                      9
# R_GROUND_landed                         12                      7
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
#                                       6960                   6961  \
# R_fighter                    Johnny Rhodes          Jason DeLucia
# B_fighter                    David Levicki            Scott Baker
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.64                    0.6
# B_SIG_STR_pct                          0.8                      0
# R_TD_pct                                 1                      0
# B_TD_pct                                 0                      1
# R_SUB_ATT                                0                      5
# B_SUB_ATT                                0                      0
# R_REV                                    0                      4
# B_REV                                    0                      2
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                              KO/TKO             Submission
# last_round                               1                      1
# last_round_time                      12:13                   6:41
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Johnny Rhodes          Jason DeLucia
# R_SIG_STR._att                          17                      5
# R_SIG_STR._landed                       11                      3
# B_SIG_STR._att                           5                      2
# B_SIG_STR._landed                        4                      0
# R_TOTAL_STR._att                        86                     25
# R_TOTAL_STR._landed                     74                     20
# B_TOTAL_STR._att                       102                     23
# B_TOTAL_STR._landed                     95                     14
# R_TD_att                                 1                      1
# R_TD_landed                              1                      0
# B_TD_att                                 0                      1
# B_TD_landed                              0                      1
# R_HEAD_att                              15                      2
# R_HEAD_landed                            9                      1
# B_HEAD_att                               5                      2
# B_HEAD_landed                            4                      0
# R_BODY_att                               1                      2
# R_BODY_landed                            1                      1
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                1                      1
# R_LEG_landed                             1                      1
# B_LEG_att                                0                      0
# B_LEG_landed                             0                      0
# R_DISTANCE_att                           1                      4
# R_DISTANCE_landed                        1                      2
# B_DISTANCE_att                           2                      2
# B_DISTANCE_landed                        1                      0
# R_CLINCH_att                             1                      0
# R_CLINCH_landed                          1                      0
# B_CLINCH_att                             2                      0
# B_CLINCH_landed                          2                      0
# R_GROUND_att                            15                      1
# R_GROUND_landed                          9                      1
# B_GROUND_att                             1                      0
# B_GROUND_landed                          1                      0
#
#                                       6962                   6963  \
# R_fighter                    Remco Pardoel          Frank Hamaker
# B_fighter               Alberta Cerra Leon        Thaddeus Luster
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.66                   0.66
# B_SIG_STR_pct                         0.33                      0
# R_TD_pct                                 1                      1
# B_TD_pct                                 0                      0
# R_SUB_ATT                                1                      3
# B_SUB_ATT                                0                      0
# R_REV                                    0                      1
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       9:51                   4:52
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Remco Pardoel          Frank Hamaker
# R_SIG_STR._att                           6                      3
# R_SIG_STR._landed                        4                      2
# B_SIG_STR._att                           3                      0
# B_SIG_STR._landed                        1                      0
# R_TOTAL_STR._att                        22                     15
# R_TOTAL_STR._landed                     20                     14
# B_TOTAL_STR._att                        11                      0
# B_TOTAL_STR._landed                      9                      0
# R_TD_att                                 1                      1
# R_TD_landed                              1                      1
# B_TD_att                                 0                      1
# B_TD_landed                              0                      0
# R_HEAD_att                               5                      3
# R_HEAD_landed                            4                      2
# B_HEAD_att                               3                      0
# B_HEAD_landed                            1                      0
# R_BODY_att                               0                      0
# R_BODY_landed                            0                      0
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                1                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                0                      0
# B_LEG_landed                             0                      0
# R_DISTANCE_att                           1                      1
# R_DISTANCE_landed                        0                      1
# B_DISTANCE_att                           1                      0
# B_DISTANCE_landed                        1                      0
# R_CLINCH_att                             0                      0
# R_CLINCH_landed                          0                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             5                      2
# R_GROUND_landed                          4                      1
# B_GROUND_att                             2                      0
# B_GROUND_landed                          0                      0
#
#                                       6964                   6965
# R_fighter                     Scott Morris          Patrick Smith
# B_fighter                   Sean Daugherty             Ray Wizard
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                            1                      1
# B_SIG_STR_pct                            0                      1
# R_TD_pct                                 1                      0
# B_TD_pct                                 0                      0
# R_SUB_ATT                                1                      1
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       0:20                   0:58
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                        Scott Morris          Patrick Smith
# R_SIG_STR._att                           1                      1
# R_SIG_STR._landed                        1                      1
# B_SIG_STR._att                           4                      1
# B_SIG_STR._landed                        0                      1
# R_TOTAL_STR._att                         2                      1
# R_TOTAL_STR._landed                      2                      1
# B_TOTAL_STR._att                         5                      2
# B_TOTAL_STR._landed                      1                      2
# R_TD_att                                 1                      1
# R_TD_landed                              1                      0
# B_TD_att                                 0                      0
# B_TD_landed                              0                      0
# R_HEAD_att                               1                      0
# R_HEAD_landed                            1                      0
# B_HEAD_att                               2                      0
# B_HEAD_landed                            0                      0
# R_BODY_att                               0                      1
# R_BODY_landed                            0                      1
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                2                      1
# B_LEG_landed                             0                      1
# R_DISTANCE_att                           0                      0
# R_DISTANCE_landed                        0                      0
# B_DISTANCE_att                           3                      1
# B_DISTANCE_landed                        0                      1
# R_CLINCH_att                             1                      1
# R_CLINCH_landed                          1                      1
# B_CLINCH_att                             1                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             0                      0
# R_GROUND_landed                          0                      0
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
# [59 rows x 6966 columns]

# %% [markdown]
# ### Creating a title_bout feature and weight_class

# %%
df['Fight_type'].value_counts()
# Out:
# Lightweight Bout                                                     1169
# Welterweight Bout                                                    1138
# Middleweight Bout                                                     884
# Featherweight Bout                                                    634
# Heavyweight Bout                                                      598
#                                                                      ...
# Ultimate Fighter 11 Middleweight Tournament Title Bout                  1
# Ultimate Fighter 1 Middleweight Tournament Title Bout                   1
# Ultimate Fighter 19 Light Heavyweight Tournament Title Bout             1
# Ultimate Fighter Latin America Bantamweight Tournament Title Bout       1
# Ultimate Fighter Brazil 4 Bantamweight Tournament Title Bout            1
# Name: Fight_type, Length: 109, dtype: int64

# %%
df['Fight_type'].value_counts()[df['Fight_type'].value_counts() > 1].index
# Out:
# Index(['Lightweight Bout', 'Welterweight Bout', 'Middleweight Bout',
#        'Featherweight Bout', 'Heavyweight Bout', 'Light Heavyweight Bout',
#        'Bantamweight Bout', 'Flyweight Bout', 'Women's Strawweight Bout',
#        'Women's Flyweight Bout', 'Women's Bantamweight Bout',
#        'Open Weight Bout', 'Catch Weight Bout',
#        'UFC Light Heavyweight Title Bout', 'UFC Welterweight Title Bout',
#        'UFC Heavyweight Title Bout', 'UFC Middleweight Title Bout',
#        'UFC Lightweight Title Bout', 'UFC Flyweight Title Bout',
#        'Women's Featherweight Bout', 'UFC Featherweight Title Bout',
#        'UFC Bantamweight Title Bout', 'UFC Women's Strawweight Title Bout',
#        'UFC Women's Bantamweight Title Bout',
#        'UFC Women's Flyweight Title Bout',
#        'UFC Interim Heavyweight Title Bout',
#        'UFC Women's Featherweight Title Bout',
#        'UFC Superfight Championship Bout',
#        'UFC Interim Bantamweight Title Bout',
#        'UFC Interim Featherweight Title Bout',
#        'UFC Interim Middleweight Title Bout',
#        'UFC Interim Lightweight Title Bout',
#        'UFC Interim Welterweight Title Bout',
#        'UFC Interim Light Heavyweight Title Bout'],
#       dtype='object')

# %%
df['title_bout'] = df['Fight_type'].apply(lambda X: True if 'Title Bout' in X else False)

# %%
def make_weight_class(X):
    for weight_class in weight_classes:
        if weight_class in X:
            return weight_class
    if X == 'Catch Weight Bout' or 'Catchweight Bout':
        return 'Catch Weight'
    else:
        return 'Open Weight'

# %%
weight_classes = ['Women\'s Strawweight', 'Women\'s Bantamweight', 
                  'Women\'s Featherweight', 'Women\'s Flyweight', 'Lightweight', 
                  'Welterweight', 'Middleweight','Light Heavyweight', 
                  'Heavyweight', 'Featherweight','Bantamweight', 'Flyweight', 'Open Weight']

df['weight_class'] = df['Fight_type'].apply(make_weight_class)

# %%
df[df['weight_class'].isnull()]['Fight_type'].value_counts()
# Out:
# Series([], Name: Fight_type, dtype: int64)

# %% [markdown]
# ### Creating total_time_fought

# %%
df['Format'].value_counts()
# Out:
# 3 Rnd (5-5-5)           6136
# 5 Rnd (5-5-5-5-5)        606
# 1 Rnd + OT (12-3)         80
# 3 Rnd + OT (5-5-5-5)      30
# No Time Limit             29
# 1 Rnd (20)                21
# 1 Rnd + 2OT (15-3-3)      20
# 2 Rnd (5-5)               14
# 1 Rnd (15)                 8
# 1 Rnd (10)                 6
# 1 Rnd (12)                 4
# 1 Rnd + OT (30-5)          3
# 1 Rnd + OT (15-3)          2
# 1 Rnd (18)                 2
# 1 Rnd + OT (27-3)          1
# 1 Rnd (30)                 1
# 1 Rnd + 2OT (24-3-3)       1
# 1 Rnd + OT (30-3)          1
# 1 Rnd + OT (31-5)          1
# Name: Format, dtype: int64

# %%
df['Format'].value_counts().index
# Out:
# Index(['3 Rnd (5-5-5)', '5 Rnd (5-5-5-5-5)', '1 Rnd + OT (12-3)',
#        '3 Rnd + OT (5-5-5-5)', 'No Time Limit', '1 Rnd (20)',
#        '1 Rnd + 2OT (15-3-3)', '2 Rnd (5-5)', '1 Rnd (15)', '1 Rnd (10)',
#        '1 Rnd (12)', '1 Rnd + OT (30-5)', '1 Rnd + OT (15-3)', '1 Rnd (18)',
#        '1 Rnd + OT (27-3)', '1 Rnd (30)', '1 Rnd + 2OT (24-3-3)',
#        '1 Rnd + OT (30-3)', '1 Rnd + OT (31-5)'],
#       dtype='object')

# %%
time_in_first_round = {'3 Rnd (5-5-5)': 5*60, '5 Rnd (5-5-5-5-5)': 5*60, '1 Rnd + OT (12-3)': 12*60,
       'No Time Limit': 1, '3 Rnd + OT (5-5-5-5)': 5*60, '1 Rnd (20)': 1*20,
       '2 Rnd (5-5)': 5*60, '1 Rnd (15)': 15*60, '1 Rnd (10)': 10*60,
       '1 Rnd (12)':12*60, '1 Rnd + OT (30-5)': 30*60, '1 Rnd (18)': 18*60, '1 Rnd + OT (15-3)': 15*60,
       '1 Rnd (30)': 30*60, '1 Rnd + OT (31-5)': 31*5,
       '1 Rnd + OT (27-3)': 27*60, '1 Rnd + OT (30-3)': 30*60}

exception_format_time = {'1 Rnd + 2OT (15-3-3)': [15*60, 3*60], '1 Rnd + 2OT (24-3-3)': [24*60, 3*60]}

# '1 Rnd + 2OT (15-3-3)' and '1 Rnd + 2OT (24-3-3)' is not included because it has 3 uneven timed rounds. 
# We'll have to deal with it separately

# %%
# Converting to seconds
df['last_round_time'] = df['last_round_time'].apply(lambda X: int(X.split(':')[0])*60 + int(X.split(':')[1]))

# %%
def get_total_time(row):
    if row['Format'] in time_in_first_round.keys():
        return (row['last_round'] - 1) * time_in_first_round[row['Format']] + row['last_round_time']
    elif row['Format'] in exception_format_time.keys():
        if (row['last_round'] - 1) >= 2:
            return exception_format_time[row['Format']][0] + (row['last_round'] - 2) * \
                    exception_format_time[row['Format']][1] + row['last_round_time']
        else:
            return (row['last_round'] - 1) * exception_format_time[row['Format']][0] + row['last_round_time']
    
# So if the fight ended in round 1, we only need last_round_time. 
# If it ended in round 2, we need the full time of round 1 and the last_round_time
# This works for fights with same time in each round and fights with only two rounds.

# %%
df['total_time_fought(seconds)'] = df.apply(get_total_time, axis=1)

# %%
def get_no_of_rounds(X):
    if X == 'No Time Limit':
        return 1
    else:
        return len(X.split('(')[1].replace(')', '').split('-'))

df['no_of_rounds'] = df['Format'].apply(get_no_of_rounds)

# %%
df
# Out:
#                  R_fighter            B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0     Jack Della Maddalena          Randy Brown     1     0           0.45
# 1              Tyson Pedro   Modestas Bukauskas     0     0           0.55
# 2             Shannon Ross   Kleydson Rodrigues     0     1           0.25
# 3              Justin Tafa        Parker Porter     1     0           0.50
# 4             Josh Culibao  Melsik Baghdasaryan     0     0           0.35
# ...                    ...                  ...   ...   ...            ...
# 6961         Jason DeLucia          Scott Baker     0     0           0.60
# 6962         Remco Pardoel   Alberta Cerra Leon     0     0           0.66
# 6963         Frank Hamaker      Thaddeus Luster     0     0           0.66
# 6964          Scott Morris       Sean Daugherty     0     0           1.00
# 6965         Patrick Smith           Ray Wizard     0     0           1.00
#
#       B_SIG_STR_pct  R_TD_pct  B_TD_pct  R_SUB_ATT  B_SUB_ATT  ...  \
# 0              0.28      0.00       0.0          1          0  ...
# 1              0.40      0.66       0.0          0          0  ...
# 2              0.63      0.00       0.0          0          0  ...
# 3              0.43      0.00       0.0          0          0  ...
# 4              0.59      0.00       0.0          1          0  ...
# ...             ...       ...       ...        ...        ...  ...
# 6961           0.00      0.00       1.0          5          0  ...
# 6962           0.33      1.00       0.0          1          0  ...
# 6963           0.00      1.00       0.0          3          0  ...
# 6964           0.00      1.00       0.0          1          0  ...
# 6965           1.00      0.00       0.0          1          0  ...
#
#       B_CLINCH_att  B_CLINCH_landed R_GROUND_att R_GROUND_landed B_GROUND_att  \
# 0                0                0           11               7            0
# 1               14               10            1               1            0
# 2                7                5            0               0            1
# 3                1                0            0               0            0
# 4                3                2            0               0            0
# ...            ...              ...          ...             ...          ...
# 6961             0                0            1               1            0
# 6962             0                0            5               4            2
# 6963             0                0            2               1            0
# 6964             1                0            0               0            0
# 6965             0                0            0               0            0
#
#       B_GROUND_landed  title_bout       weight_class  \
# 0                   0       False       Welterweight
# 1                   0       False  Light Heavyweight
# 2                   0       False          Flyweight
# 3                   0       False        Heavyweight
# 4                   0       False      Featherweight
# ...               ...         ...                ...
# 6961                0       False        Open Weight
# 6962                0       False        Open Weight
# 6963                0       False        Open Weight
# 6964                0       False        Open Weight
# 6965                0       False        Open Weight
#
#      total_time_fought(seconds) no_of_rounds
# 0                           133            3
# 1                           900            3
# 2                            59            3
# 3                            66            3
# 4                           422            3
# ...                         ...          ...
# 6961                        401            1
# 6962                        591            1
# 6963                        292            1
# 6964                         20            1
# 6965                         58            1
#
# [6966 rows x 63 columns]

# %%
df.drop(['Format', 'Fight_type', 'last_round_time'], axis = 1, inplace=True)

# %% [markdown]
# ### Create CTRL_time(seconds)

# %%
CTRL_columns = ['R_CTRL','B_CTRL']

def conv_to_sec(X):
    if X != '--':
        return int(X.split(':')[0])*60 + int(X.split(':')[1])
    else:
        # if '--' means there was no time spent on the ground. 
        # Taking a call here to consider this as 0 seconds
        return 0

for column in CTRL_columns:
    df[column+'_time(seconds)'] = df[column].apply(conv_to_sec)

# %%
df.T
# Out:
#                                             0                   1     \
# R_fighter                   Jack Della Maddalena         Tyson Pedro
# B_fighter                            Randy Brown  Modestas Bukauskas
# R_KD                                           1                   0
# B_KD                                           0                   0
# R_SIG_STR_pct                               0.45                0.55
# ...                                          ...                 ...
# weight_class                        Welterweight   Light Heavyweight
# total_time_fought(seconds)                   133                 900
# no_of_rounds                                   3                   3
# R_CTRL_time(seconds)                          15                 181
# B_CTRL_time(seconds)                           0                  57
#
#                                           2              3     \
# R_fighter                         Shannon Ross    Justin Tafa
# B_fighter                   Kleydson Rodrigues  Parker Porter
# R_KD                                         0              1
# B_KD                                         1              0
# R_SIG_STR_pct                             0.25            0.5
# ...                                        ...            ...
# weight_class                         Flyweight    Heavyweight
# total_time_fought(seconds)                  59             66
# no_of_rounds                                 3              3
# R_CTRL_time(seconds)                         0              0
# B_CTRL_time(seconds)                         0              0
#
#                                            4                  5     \
# R_fighter                          Josh Culibao        Jimmy Crute
# B_fighter                   Melsik Baghdasaryan   Alonzo Menifield
# R_KD                                          0                  0
# B_KD                                          0                  2
# R_SIG_STR_pct                              0.35                0.5
# ...                                         ...                ...
# weight_class                      Featherweight  Light Heavyweight
# total_time_fought(seconds)                  422                900
# no_of_rounds                                  3                  3
# R_CTRL_time(seconds)                         14                475
# B_CTRL_time(seconds)                          0                235
#
#                                              6               7     \
# R_fighter                         Islam Makhachev  Yair Rodriguez
# B_fighter                   Alexander Volkanovski     Josh Emmett
# R_KD                                            0               0
# B_KD                                            1               0
# R_SIG_STR_pct                                 0.6            0.57
# ...                                           ...             ...
# weight_class                          Lightweight   Featherweight
# total_time_fought(seconds)                   1500             559
# no_of_rounds                                    5               5
# R_CTRL_time(seconds)                          457               0
# B_CTRL_time(seconds)                          175             181
#
#                                      8                    9     ...  \
# R_fighter                     Shane Young     Loma Lookboonmee  ...
# B_fighter                    Blake Bilder           Elise Reed  ...
# R_KD                                    0                    0  ...
# B_KD                                    0                    0  ...
# R_SIG_STR_pct                         0.4                 0.62  ...
# ...                                   ...                  ...  ...
# weight_class                Featherweight  Women's Strawweight  ...
# total_time_fought(seconds)            900                  344  ...
# no_of_rounds                            3                    3  ...
# R_CTRL_time(seconds)                    3                   36  ...
# B_CTRL_time(seconds)                  103                  119  ...
#
#                                      6956             6957           6958  \
# R_fighter                   Johnny Rhodes     Royce Gracie  Patrick Smith
# B_fighter                     Fred Ettish  Minoki Ichihara   Scott Morris
# R_KD                                    1                0              0
# B_KD                                    0                0              0
# R_SIG_STR_pct                        0.44              0.5           0.76
# ...                                   ...              ...            ...
# weight_class                  Open Weight      Open Weight    Open Weight
# total_time_fought(seconds)            187              308             30
# no_of_rounds                            1                1              1
# R_CTRL_time(seconds)                    0                0              0
# B_CTRL_time(seconds)                    0                0              0
#
#                                         6959           6960           6961  \
# R_fighter                       Orlando Wiet  Johnny Rhodes  Jason DeLucia
# B_fighter                   Robert Lucarelli  David Levicki    Scott Baker
# R_KD                                       0              0              0
# B_KD                                       0              0              0
# R_SIG_STR_pct                           0.66           0.64            0.6
# ...                                      ...            ...            ...
# weight_class                     Open Weight    Open Weight    Open Weight
# total_time_fought(seconds)               170            733            401
# no_of_rounds                               1              1              1
# R_CTRL_time(seconds)                       0              0              0
# B_CTRL_time(seconds)                       0              0              0
#
#                                           6962             6963  \
# R_fighter                        Remco Pardoel    Frank Hamaker
# B_fighter                   Alberta Cerra Leon  Thaddeus Luster
# R_KD                                         0                0
# B_KD                                         0                0
# R_SIG_STR_pct                             0.66             0.66
# ...                                        ...              ...
# weight_class                       Open Weight      Open Weight
# total_time_fought(seconds)                 591              292
# no_of_rounds                                 1                1
# R_CTRL_time(seconds)                         0                0
# B_CTRL_time(seconds)                         0                0
#
#                                       6964           6965
# R_fighter                     Scott Morris  Patrick Smith
# B_fighter                   Sean Daugherty     Ray Wizard
# R_KD                                     0              0
# B_KD                                     0              0
# R_SIG_STR_pct                            1              1
# ...                                    ...            ...
# weight_class                   Open Weight    Open Weight
# total_time_fought(seconds)              20             58
# no_of_rounds                             1              1
# R_CTRL_time(seconds)                     0              0
# B_CTRL_time(seconds)                     0              0
#
# [62 rows x 6966 columns]

# %%
df.drop(['R_CTRL','B_CTRL'], axis = 1, inplace=True)

# %% [markdown]
# ### Create another DataFrame to save the compiled data per fighter (Our Prediction DataFrame)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'win_by', 'last_round', 'Referee', 'date', 'location',
#        'Winner', 'R_SIG_STR._att', 'R_SIG_STR._landed', 'B_SIG_STR._att',
#        'B_SIG_STR._landed', 'R_TOTAL_STR._att', 'R_TOTAL_STR._landed',
#        'B_TOTAL_STR._att', 'B_TOTAL_STR._landed', 'R_TD_att', 'R_TD_landed',
#        'B_TD_att', 'B_TD_landed', 'R_HEAD_att', 'R_HEAD_landed', 'B_HEAD_att',
#        'B_HEAD_landed', 'R_BODY_att', 'R_BODY_landed', 'B_BODY_att',
#        'B_BODY_landed', 'R_LEG_att', 'R_LEG_landed', 'B_LEG_att',
#        'B_LEG_landed', 'R_DISTANCE_att', 'R_DISTANCE_landed', 'B_DISTANCE_att',
#        'B_DISTANCE_landed', 'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att',
#        'B_CLINCH_landed', 'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att',
#        'B_GROUND_landed', 'title_bout', 'weight_class',
#        'total_time_fought(seconds)', 'no_of_rounds', 'R_CTRL_time(seconds)',
#        'B_CTRL_time(seconds)'],
#       dtype='object')

# %%
df2 = df.copy()

# %%
df2.drop(['R_KD', 'B_KD', 'R_SIG_STR_pct',
       'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
       'R_CTRL_time(seconds)', 'B_CTRL_time(seconds)', 'R_REV', 'B_REV', 'win_by', 'last_round', 
        'R_SIG_STR._att', 'R_SIG_STR._landed',
       'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
       'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
       'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
       'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
       'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
       'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
       'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
       'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
       'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed',
        'total_time_fought(seconds)'], axis = 1, inplace=True)
df2
# Out:
#                  R_fighter            B_fighter         Referee  \
# 0     Jack Della Maddalena          Randy Brown    Marc Goddard
# 1              Tyson Pedro   Modestas Bukauskas  Steve Perceval
# 2             Shannon Ross   Kleydson Rodrigues      Matt Wynne
# 3              Justin Tafa        Parker Porter    Jason Herzog
# 4             Josh Culibao  Melsik Baghdasaryan  Peter Hickmott
# ...                    ...                  ...             ...
# 6961         Jason DeLucia          Scott Baker   John McCarthy
# 6962         Remco Pardoel   Alberta Cerra Leon   John McCarthy
# 6963         Frank Hamaker      Thaddeus Luster   John McCarthy
# 6964          Scott Morris       Sean Daugherty   John McCarthy
# 6965         Patrick Smith           Ray Wizard   John McCarthy
#
#                    date                             location  \
# 0     February 11, 2023  Perth, Western Australia, Australia
# 1     February 11, 2023  Perth, Western Australia, Australia
# 2     February 11, 2023  Perth, Western Australia, Australia
# 3     February 11, 2023  Perth, Western Australia, Australia
# 4     February 11, 2023  Perth, Western Australia, Australia
# ...                 ...                                  ...
# 6961     March 11, 1994                Denver, Colorado, USA
# 6962     March 11, 1994                Denver, Colorado, USA
# 6963     March 11, 1994                Denver, Colorado, USA
# 6964     March 11, 1994                Denver, Colorado, USA
# 6965     March 11, 1994                Denver, Colorado, USA
#
#                     Winner  title_bout       weight_class  no_of_rounds
# 0     Jack Della Maddalena       False       Welterweight             3
# 1       Modestas Bukauskas       False  Light Heavyweight             3
# 2       Kleydson Rodrigues       False          Flyweight             3
# 3              Justin Tafa       False        Heavyweight             3
# 4             Josh Culibao       False      Featherweight             3
# ...                    ...         ...                ...           ...
# 6961         Jason DeLucia       False        Open Weight             1
# 6962         Remco Pardoel       False        Open Weight             1
# 6963         Frank Hamaker       False        Open Weight             1
# 6964          Scott Morris       False        Open Weight             1
# 6965         Patrick Smith       False        Open Weight             1
#
# [6966 rows x 9 columns]

# %% [markdown]
# ### Compiling Data per fighter

# %%
red_fighters = df['R_fighter'].value_counts().index
blue_fighters = df['B_fighter'].value_counts().index

fighters = list(set(red_fighters) | set(blue_fighters))

# %%
def get_renamed_winner(row):
    if row['R_fighter'] == row['Winner']:
        return 'Red'
    elif row['B_fighter'] == row['Winner']:
        return 'Blue'
    elif row['Winner'] == 'Draw':
        return 'Draw'

df2['Winner'] = df2[['R_fighter', 'B_fighter', 'Winner']].apply(get_renamed_winner, axis=1)

# %%
df = pd.concat([df,pd.get_dummies(df['win_by'], prefix='win_by')],axis=1)
df.drop(['win_by'],axis=1, inplace=True)

# %%
Numerical_columns = ['hero_KD', 'opp_KD', 'hero_SIG_STR_pct',
       'opp_SIG_STR_pct', 'hero_TD_pct', 'opp_TD_pct', 'hero_SUB_ATT', 'opp_SUB_ATT',
        'hero_REV', 'opp_REV', 'hero_SIG_STR._att', 'hero_SIG_STR._landed',
       'opp_SIG_STR._att', 'opp_SIG_STR._landed', 'hero_TOTAL_STR._att',
       'hero_TOTAL_STR._landed', 'opp_TOTAL_STR._att', 'opp_TOTAL_STR._landed',
       'hero_TD_att', 'hero_TD_landed', 'opp_TD_att', 'opp_TD_landed', 'hero_HEAD_att',
       'hero_HEAD_landed', 'opp_HEAD_att', 'opp_HEAD_landed', 'hero_BODY_att',
       'hero_BODY_landed', 'opp_BODY_att', 'opp_BODY_landed', 'hero_LEG_att',
       'hero_LEG_landed', 'opp_LEG_att', 'opp_LEG_landed', 'hero_DISTANCE_att',
       'hero_DISTANCE_landed', 'opp_DISTANCE_att', 'opp_DISTANCE_landed',
       'hero_CLINCH_att', 'hero_CLINCH_landed', 'opp_CLINCH_att', 'opp_CLINCH_landed',
       'hero_GROUND_att', 'hero_GROUND_landed', 'opp_GROUND_att', 'opp_GROUND_landed', 
        'hero_CTRL_time(seconds)', 'opp_CTRL_time(seconds)',
       'total_time_fought(seconds)']

Categorical_columns = ['win_by', 'last_round',
        'Winner', 'title_bout']

# %% [markdown]
# For all `Numerical_columns`, we take the average of those columns for every fighter of every fight they had up until that point.
#
# For `Categorical_columns`, we have to come up with different ideas for each column:
#
# * Each `win_by` will be a column of it's own
# * from `last_round` we can get, `total_rounds_fought`
# * from `total_time_fought` we can get `average_time_fought`
# * from `Winner` we get `wins`, `losses`, `draw`, `current_streak`, `longest_streak`
# * from `title_bout` we can get `no_of_title_fights`

# %%
import re

def lreplace(pattern, sub, string):
    """
    Replaces 'pattern' in 'string' with 'sub' if 'pattern' starts 'string'.
    """
    return re.sub('^%s' % pattern, sub, string)

# %%
red = df.groupby('R_fighter')
blue = df.groupby('B_fighter')

# %%
def get_fighter_red(fighter_name):
    try:
        fighter_red = red.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_red.columns:
        if re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'hero_', column)
        elif re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'opp_', column)
    fighter_red = fighter_red.rename(rename_columns, axis='columns')
    return fighter_red

# %%
def get_fighter_blue(fighter_name):
    try:
        fighter_blue = blue.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_blue.columns:
        if re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'hero_', column)
        elif re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'opp_', column)
    fighter_blue = fighter_blue.rename(rename_columns, axis='columns')
    return fighter_blue

# %%
def get_result_stats(result_list):
    result_list.reverse() # To get it in ascending order
    current_win_streak = 0
    current_lose_streak = 0
    longest_win_streak = 0
    wins = 0
    losses = 0
    draw = 0
    for result in result_list:
        if result == 'hero':
            wins += 1
            current_win_streak += 1
            current_lose_streak = 0
            if longest_win_streak < current_win_streak:
                longest_win_streak += 1
        elif result == 'opp':
            losses += 1
            current_win_streak = 0
            current_lose_streak += 1
        elif result == 'draw':
            draw += 1
            current_lose_streak = 0
            current_win_streak = 0
            
    return current_win_streak, current_lose_streak, longest_win_streak, wins, losses, draw

# %%
win_by_columns = ['win_by_Decision - Majority', 'win_by_Decision - Split',
       'win_by_Decision - Unanimous', 'win_by_KO/TKO','win_by_Submission',
       'win_by_TKO - Doctor\'s Stoppage']

# %%
temp_blue_frame = pd.DataFrame()
temp_red_frame = pd.DataFrame()
result_stats = ['current_win_streak', 'current_lose_streak', 'longest_win_streak', 'wins', 'losses', 'draw']

for fighter_name in fighters:
    fighter_red = get_fighter_red(fighter_name)
    fighter_blue = get_fighter_blue(fighter_name)
    fighter_index = None
    
    if fighter_red is None:
        fighter = fighter_blue
        fighter_index = 'blue'
    elif fighter_blue is None:
        fighter = fighter_red
        fighter_index = 'red'
    else:
        fighter = pd.concat([fighter_red, fighter_blue]).sort_index()
    
    fighter['Winner'] = fighter['Winner'].apply(lambda X: 'hero' if X == fighter_name else 'opp')

    for i, index in enumerate(fighter.index):
        fighter_slice = fighter[(i+1):].sort_index(ascending=False)
        s = fighter_slice[Numerical_columns].ewm(span=3, adjust=False).mean().tail(1)
        if len(s) != 0:
            pass
        else:
            s.loc[len(s)] = [np.NaN for _ in s.columns]
        s['total_rounds_fought'] = fighter_slice['last_round'].sum()
        s['total_title_bouts'] = fighter_slice[fighter_slice['title_bout']==True]['title_bout'].count()
        s['hero_fighter'] = fighter_name
        results = get_result_stats(list(fighter_slice['Winner']))
        for result_stat, result in zip(result_stats, results):
            s[result_stat] = result
        win_by_results = fighter_slice[fighter_slice['Winner'] == 'hero'][win_by_columns].sum()
        for win_by_column,win_by_result in zip(win_by_columns, win_by_results):
            s[win_by_column] = win_by_result
        s.index = [index]


        if fighter_index is None:
            if index in fighter_blue.index:
                temp_blue_frame = temp_blue_frame.append(s)
            elif index in fighter_red.index:
                temp_red_frame = temp_red_frame.append(s)
        elif fighter_index == 'blue':
            temp_blue_frame = temp_blue_frame.append(s)
        elif fighter_index == 'red':
            temp_red_frame = temp_red_frame.append(s)

# %%
temp_blue_frame.T
# Out:
#                                     5267    6039  1738  2088  4647 4767  \
# hero_KD                           0.3125       1     0     0     1  NaN
# opp_KD                                 0       0   0.5     0     0  NaN
# hero_SIG_STR_pct                0.391523  0.6775  0.45  0.47  0.42  NaN
# opp_SIG_STR_pct                 0.454727  0.4725  0.41   0.4  0.43  NaN
# hero_TD_pct                     0.296406    0.33     0     0     1  NaN
# ...                                  ...     ...   ...   ...   ...  ...
# win_by_Decision - Split                1       0     0     0     0    0
# win_by_Decision - Unanimous            3       1     0     0     1    0
# win_by_KO/TKO                          3       2     0     0     0    0
# win_by_Submission                      0       0     0     0     0    0
# win_by_TKO - Doctor's Stoppage         0       0     0     0     0    0
#
#                                     6118     6185  6425 6501  ... 6033  \
# hero_KD                            0.125     0.25     0  NaN  ...  NaN
# opp_KD                            0.5625    0.125     1  NaN  ...  NaN
# hero_SIG_STR_pct                0.520625  0.61125  0.92  NaN  ...  NaN
# opp_SIG_STR_pct                   0.5625    0.605  0.85  NaN  ...  NaN
# hero_TD_pct                     0.459375  0.25875   0.5  NaN  ...  NaN
# ...                                  ...      ...   ...  ...  ...  ...
# win_by_Decision - Split                0        0     0    0  ...    0
# win_by_Decision - Unanimous            0        0     0    0  ...    0
# win_by_KO/TKO                          2        2     0    0  ...    0
# win_by_Submission                      0        0     0    0  ...    0
# win_by_TKO - Doctor's Stoppage         0        0     0    0  ...    0
#
#                                      5684      5803      5890      6071  \
# hero_KD                          0.157227  0.314453  0.628906  0.515625
# opp_KD                             1.2832   1.56641   1.13281   0.53125
# hero_SIG_STR_pct                 0.264932  0.359863  0.379727  0.508906
# opp_SIG_STR_pct                  0.534619  0.449238  0.528477  0.403906
# hero_TD_pct                     0.0664062  0.132812  0.265625    0.0625
# ...                                   ...       ...       ...       ...
# win_by_Decision - Split                 2         2         2         1
# win_by_Decision - Unanimous             2         2         2         2
# win_by_KO/TKO                           2         2         2         2
# win_by_Submission                       0         0         0         0
# win_by_TKO - Doctor's Stoppage          0         0         0         0
#
#                                     6252   6434   3961  4427 4553
# hero_KD                           0.0625    0.5      0     0  NaN
# opp_KD                             0.125      0    0.5     1  NaN
# hero_SIG_STR_pct                0.475625  0.345   0.43  0.25  NaN
# opp_SIG_STR_pct                 0.325625  0.235  0.495  0.45  NaN
# hero_TD_pct                         0.25      0      0     0  NaN
# ...                                  ...    ...    ...   ...  ...
# win_by_Decision - Split                0      0      0     0    0
# win_by_Decision - Unanimous            2      1      0     0    0
# win_by_KO/TKO                          2      1      0     0    0
# win_by_Submission                      0      0      0     0    0
# win_by_TKO - Doctor's Stoppage         0      0      0     0    0
#
# [64 rows x 6966 columns]

# %% [markdown]
# ### Adding fighter details like height, weight, reach, stance and dob

# %%
fighter_details = fighter_details[fighter_details.index.isin(fighters)]
for col in fighter_details.columns:
    print(f"Number of NaN in {col} : {fighter_details[col].isnull().sum()}")
# Out:
# Number of NaN in Height : 13
# Number of NaN in Weight : 10
# Number of NaN in Reach : 641
# Number of NaN in Stance : 74
# Number of NaN in DOB : 141

# %%
def convert_to_cms(X):
    if X is np.NaN:
        return X
    elif len(X.split("'")) == 2:
        feet = float(X.split("'")[0])
        inches = int(X.split("'")[1].replace(' ', '').replace('"',''))
        return (feet * 30.48) + (inches * 2.54)
    else:
        return float(X.replace('"','')) * 2.54

# %%
fighter_details['Height_cms'] = fighter_details['Height'].apply(convert_to_cms)
fighter_details['Reach_cms'] = fighter_details['Reach'].apply(convert_to_cms)

# %%
fighter_details['Weight_lbs'] = fighter_details['Weight'].apply(lambda X: float(X.replace(' lbs.', '')) if X is not np.NaN else X)

# %%
fighter_details.columns
# Out:
# Index(['fighter_name', 'Stance', 'DOB', 'Height_cms', 'Reach_cms',
#        'Weight_lbs'],
#       dtype='object')

# %%
fighter_details.head()
# Out:
#                   Height    Weight Reach    Stance           DOB  Height_cms  \
# fighter_name
# Danny Abbadi      5' 11"  155 lbs.   NaN  Orthodox  Jul 03, 1983      180.34
# David Abbott       6' 0"  265 lbs.   NaN    Switch           NaN      182.88
# Hamdy Abdelwahab   6' 2"  264 lbs.   72"  Southpaw  Jan 22, 1993      187.96
# Daichi Abe        5' 11"  170 lbs.   71"  Orthodox  Nov 27, 1991      180.34
# Papy Abedi        5' 11"  185 lbs.   NaN  Southpaw  Jun 30, 1978      180.34
#
#                   Reach_cms  Weight_lbs
# fighter_name
# Danny Abbadi            NaN       155.0
# David Abbott            NaN       265.0
# Hamdy Abdelwahab     182.88       264.0
# Daichi Abe           180.34       170.0
# Papy Abedi              NaN       185.0

# %%
# i dont understand this step, there seems to be the wrong df selected to try this operations on,
# since pct_column dont seem to be present in "fighter_details" dataframe
pct_columns = ['Str_Acc','Str_Def', 'TD_Acc', 'TD_Def']

def pct_to_frac(X):
    if X != np.NaN:
        return float(X.replace('%', ''))/100
    else:
        return 0

for column in pct_columns:
    fighter_details[column] = fighter_details[column].apply(pct_to_frac)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Str_Acc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-88e932b55da6> in <module>
#       8
#       9 for column in pct_columns:
# ---> 10     fighter_details[column] = fighter_details[column].apply(pct_to_frac)
#
# d:\Python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# d:\Python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Str_Acc'

# %%
fighter_details.drop(['Height', 'Weight', 'Reach'], axis=1, inplace=True)

# %%
fighter_details.reset_index(inplace=True)
temp_red_frame.reset_index(inplace=True)
temp_blue_frame.reset_index(inplace=True)

# %%
temp_blue_frame = temp_blue_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_blue_frame.set_index('index', inplace=True)

# %%
temp_blue_frame[['hero_fighter', 'fighter_name', 'Height_cms', 'Weight_lbs', 'DOB']].head(20)
# Out:
#               hero_fighter         fighter_name  Height_cms  Weight_lbs  \
# index
# 5267       Quinton Jackson      Quinton Jackson      185.42       205.0
# 6039       Quinton Jackson      Quinton Jackson      185.42       205.0
# 1738         Salim Touahri        Salim Touahri      177.80       170.0
# 2088         Salim Touahri        Salim Touahri      177.80       170.0
# 4647       Kazuki Tokudome      Kazuki Tokudome      180.34       155.0
# 4767       Kazuki Tokudome      Kazuki Tokudome      180.34       155.0
# 6118          Terry Martin         Terry Martin      172.72       185.0
# 6185          Terry Martin         Terry Martin      172.72       185.0
# 6425          Terry Martin         Terry Martin      172.72       185.0
# 6501          Terry Martin         Terry Martin      172.72       185.0
# 5966         Eddie Sanchez        Eddie Sanchez      187.96       230.0
# 6066         Eddie Sanchez        Eddie Sanchez      187.96       230.0
# 6297         Eddie Sanchez        Eddie Sanchez      187.96       230.0
# 6857   Christophe Leninger  Christophe Leninger      182.88       200.0
# 6945   Christophe Leninger  Christophe Leninger      182.88       200.0
# 1170         John Phillips        John Phillips      180.34       185.0
# 1656         John Phillips        John Phillips      180.34       185.0
# 1943         John Phillips        John Phillips      180.34       185.0
# 2116         John Phillips        John Phillips      180.34       185.0
# 720            Sarah Alpar          Sarah Alpar      162.56       135.0
#
#                 DOB
# index
# 5267   Jun 20, 1978
# 6039   Jun 20, 1978
# 1738   Sep 28, 1989
# 2088   Sep 28, 1989
# 4647   Mar 04, 1987
# 4767   Mar 04, 1987
# 6118   Oct 10, 1980
# 6185   Oct 10, 1980
# 6425   Oct 10, 1980
# 6501   Oct 10, 1980
# 5966   Nov 04, 1982
# 6066   Nov 04, 1982
# 6297   Nov 04, 1982
# 6857            NaN
# 6945            NaN
# 1170   Jun 09, 1985
# 1656   Jun 09, 1985
# 1943   Jun 09, 1985
# 2116   Jun 09, 1985
# 720    Jun 01, 1991

# %%
temp_red_frame = temp_red_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_red_frame.set_index('index', inplace=True)

# %%
temp_blue_frame.drop('fighter_name', axis=1, inplace=True)
temp_red_frame.drop('fighter_name', axis=1, inplace=True)

# %%
blue_frame = temp_blue_frame.add_prefix('B_')
red_frame = temp_red_frame.add_prefix('R_')

# %%
frame = blue_frame.join(red_frame, how='outer')

# %%
rename_cols = {}
for col in frame.columns:
    if 'hero' in col:
        rename_cols[col] = col.replace('_hero_', '_avg_').replace('.', '')
    if 'opp' in col:
        rename_cols[col] = col.replace('_opp_', '_avg_opp_').replace('.', '')
    if 'win_by' in col:
        rename_cols[col] = col.replace(' ', '').replace('-', '_').replace('\'s', '_')

# %%
frame.rename(rename_cols, axis='columns', inplace=True)

# %%
frame.drop(['R_avg_fighter','B_avg_fighter'], axis=1, inplace=True)

# %%
df2 = df2.join(frame, how='outer')

# %% [markdown]
# ### Create Age

# %%
df2['R_DOB'] = pd.to_datetime(df2['R_DOB'])
df2['B_DOB'] = pd.to_datetime(df2['B_DOB'])
df2['date'] = pd.to_datetime(df2['date'])

# %%
def get_age(row):
    B_age = (row['date'] - row['B_DOB']).days
    R_age = (row['date'] - row['R_DOB']).days
    if np.isnan(B_age)!=True:
        B_age = math.floor(B_age/365.25)
    if np.isnan(R_age)!=True:
        R_age = math.floor(R_age/365.25)
    return pd.Series([B_age, R_age], index=['B_age', 'R_age'])

# %%
df2[['B_age', 'R_age']]= df2[['date', 'R_DOB', 'B_DOB']].apply(get_age, axis=1)

# %%
df2.drop(['R_DOB', 'B_DOB'], axis=1, inplace=True)

# %%
# df2.drop(df2.index[df2['Winner'] == 'draw'], inplace = True)

# %%
df2.to_csv('../data/data.csv', index=False)

# %%
df2
# Out:
#                  R_fighter            B_fighter         Referee       date  \
# 0     Jack Della Maddalena          Randy Brown    Marc Goddard 2023-02-11
# 1              Tyson Pedro   Modestas Bukauskas  Steve Perceval 2023-02-11
# 2             Shannon Ross   Kleydson Rodrigues      Matt Wynne 2023-02-11
# 3              Justin Tafa        Parker Porter    Jason Herzog 2023-02-11
# 4             Josh Culibao  Melsik Baghdasaryan  Peter Hickmott 2023-02-11
# ...                    ...                  ...             ...        ...
# 6961         Jason DeLucia          Scott Baker   John McCarthy 1994-03-11
# 6962         Remco Pardoel   Alberta Cerra Leon   John McCarthy 1994-03-11
# 6963         Frank Hamaker      Thaddeus Luster   John McCarthy 1994-03-11
# 6964          Scott Morris       Sean Daugherty   John McCarthy 1994-03-11
# 6965         Patrick Smith           Ray Wizard   John McCarthy 1994-03-11
#
#                                  location Winner  title_bout  \
# 0     Perth, Western Australia, Australia    Red       False
# 1     Perth, Western Australia, Australia   Blue       False
# 2     Perth, Western Australia, Australia   Blue       False
# 3     Perth, Western Australia, Australia    Red       False
# 4     Perth, Western Australia, Australia    Red       False
# ...                                   ...    ...         ...
# 6961                Denver, Colorado, USA    Red       False
# 6962                Denver, Colorado, USA    Red       False
# 6963                Denver, Colorado, USA    Red       False
# 6964                Denver, Colorado, USA    Red       False
# 6965                Denver, Colorado, USA    Red       False
#
#            weight_class  no_of_rounds  B_avg_KD  ...  \
# 0          Welterweight             3  0.570801  ...
# 1     Light Heavyweight             3  0.000000  ...
# 2             Flyweight             3  0.000000  ...
# 3           Heavyweight             3  0.000000  ...
# 4         Featherweight             3  0.500000  ...
# ...                 ...           ...       ...  ...
# 6961        Open Weight             1       NaN  ...
# 6962        Open Weight             1       NaN  ...
# 6963        Open Weight             1       NaN  ...
# 6964        Open Weight             1       NaN  ...
# 6965        Open Weight             1       NaN  ...
#
#       R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 0                               0                3                    0
# 1                               0                3                    2
# 2                               0                0                    0
# 3                               0                2                    0
# 4                               1                0                    0
# ...                           ...              ...                  ...
# 6961                            0                0                    0
# 6962                            0                0                    0
# 6963                            0                0                    0
# 6964                            0                0                    0
# 6965                            0                0                    0
#
#       R_win_by_TKO_Doctor_Stoppage  R_Stance  R_Height_cms  R_Reach_cms  \
# 0                                0    Switch        180.34       185.42
# 1                                0  Orthodox        190.50       200.66
# 2                                0    Switch        167.64       167.64
# 3                                0  Southpaw        182.88       187.96
# 4                                0  Orthodox        177.80       185.42
# ...                            ...       ...           ...          ...
# 6961                             0  Southpaw        180.34          NaN
# 6962                             0  Southpaw        190.50          NaN
# 6963                             0       NaN           NaN          NaN
# 6964                             0  Orthodox        177.80          NaN
# 6965                             0  Orthodox        187.96          NaN
#
#       R_Weight_lbs  B_age  R_age
# 0            170.0   32.0   26.0
# 1            205.0   29.0   31.0
# 2            125.0   27.0   33.0
# 3            264.0   37.0   29.0
# 4            145.0   31.0   28.0
# ...            ...    ...    ...
# 6961         190.0    NaN   24.0
# 6962         260.0    NaN    NaN
# 6963           NaN    NaN    NaN
# 6964         210.0   18.0    NaN
# 6965         225.0    NaN   30.0
#
# [6966 rows x 145 columns]

# %%
for column in df2.columns:
    print(column)
# Out:
# R_fighter
# B_fighter
# Referee
# date
# location
# Winner
# title_bout
# weight_class
# no_of_rounds
# B_avg_KD
# B_avg_opp_KD
# B_avg_SIG_STR_pct
# B_avg_opp_SIG_STR_pct
# B_avg_TD_pct
# B_avg_opp_TD_pct
# B_avg_SUB_ATT
# B_avg_opp_SUB_ATT
# B_avg_REV
# B_avg_opp_REV
# B_avg_SIG_STR_att
# B_avg_SIG_STR_landed
# B_avg_opp_SIG_STR_att
# B_avg_opp_SIG_STR_landed
# B_avg_TOTAL_STR_att
# B_avg_TOTAL_STR_landed
# B_avg_opp_TOTAL_STR_att
# B_avg_opp_TOTAL_STR_landed
# B_avg_TD_att
# B_avg_TD_landed
# B_avg_opp_TD_att
# B_avg_opp_TD_landed
# B_avg_HEAD_att
# B_avg_HEAD_landed
# B_avg_opp_HEAD_att
# B_avg_opp_HEAD_landed
# B_avg_BODY_att
# B_avg_BODY_landed
# B_avg_opp_BODY_att
# B_avg_opp_BODY_landed
# B_avg_LEG_att
# B_avg_LEG_landed
# B_avg_opp_LEG_att
# B_avg_opp_LEG_landed
# B_avg_DISTANCE_att
# B_avg_DISTANCE_landed
# B_avg_opp_DISTANCE_att
# B_avg_opp_DISTANCE_landed
# B_avg_CLINCH_att
# B_avg_CLINCH_landed
# B_avg_opp_CLINCH_att
# B_avg_opp_CLINCH_landed
# B_avg_GROUND_att
# B_avg_GROUND_landed
# B_avg_opp_GROUND_att
# B_avg_opp_GROUND_landed
# B_avg_CTRL_time(seconds)
# B_avg_opp_CTRL_time(seconds)
# B_total_time_fought(seconds)
# B_total_rounds_fought
# B_total_title_bouts
# B_current_win_streak
# B_current_lose_streak
# B_longest_win_streak
# B_wins
# B_losses
# B_draw
# B_win_by_Decision_Majority
# B_win_by_Decision_Split
# B_win_by_Decision_Unanimous
# B_win_by_KO/TKO
# B_win_by_Submission
# B_win_by_TKO_Doctor_Stoppage
# B_Stance
# B_Height_cms
# B_Reach_cms
# B_Weight_lbs
# R_avg_KD
# R_avg_opp_KD
# R_avg_SIG_STR_pct
# R_avg_opp_SIG_STR_pct
# R_avg_TD_pct
# R_avg_opp_TD_pct
# R_avg_SUB_ATT
# R_avg_opp_SUB_ATT
# R_avg_REV
# R_avg_opp_REV
# R_avg_SIG_STR_att
# R_avg_SIG_STR_landed
# R_avg_opp_SIG_STR_att
# R_avg_opp_SIG_STR_landed
# R_avg_TOTAL_STR_att
# R_avg_TOTAL_STR_landed
# R_avg_opp_TOTAL_STR_att
# R_avg_opp_TOTAL_STR_landed
# R_avg_TD_att
# R_avg_TD_landed
# R_avg_opp_TD_att
# R_avg_opp_TD_landed
# R_avg_HEAD_att
# R_avg_HEAD_landed
# R_avg_opp_HEAD_att
# R_avg_opp_HEAD_landed
# R_avg_BODY_att
# R_avg_BODY_landed
# R_avg_opp_BODY_att
# R_avg_opp_BODY_landed
# R_avg_LEG_att
# R_avg_LEG_landed
# R_avg_opp_LEG_att
# R_avg_opp_LEG_landed
# R_avg_DISTANCE_att
# R_avg_DISTANCE_landed
# R_avg_opp_DISTANCE_att
# R_avg_opp_DISTANCE_landed
# R_avg_CLINCH_att
# R_avg_CLINCH_landed
# R_avg_opp_CLINCH_att
# R_avg_opp_CLINCH_landed
# R_avg_GROUND_att
# R_avg_GROUND_landed
# R_avg_opp_GROUND_att
# R_avg_opp_GROUND_landed
# R_avg_CTRL_time(seconds)
# R_avg_opp_CTRL_time(seconds)
# R_total_time_fought(seconds)
# R_total_rounds_fought
# R_total_title_bouts
# R_current_win_streak
# R_current_lose_streak
# R_longest_win_streak
# R_wins
# R_losses
# R_draw
# R_win_by_Decision_Majority
# R_win_by_Decision_Split
# R_win_by_Decision_Unanimous
# R_win_by_KO/TKO
# R_win_by_Submission
# R_win_by_TKO_Doctor_Stoppage
# R_Stance
# R_Height_cms
# R_Reach_cms
# R_Weight_lbs
# B_age
# R_age
