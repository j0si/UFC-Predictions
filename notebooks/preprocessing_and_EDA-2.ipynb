# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('../data/data.csv')

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_rows', 200)

# %%
df.T
# Out:
#                                                              0     \
# R_fighter                                    Jack Della Maddalena
# B_fighter                                             Randy Brown
# Referee                                              Marc Goddard
# date                                                   2023-02-11
# location                      Perth, Western Australia, Australia
# Winner                                                        Red
# title_bout                                                  False
# weight_class                                         Welterweight
# no_of_rounds                                                    3
# B_avg_KD                                                 0.570801
# B_avg_opp_KD                                               0.3125
# B_avg_SIG_STR_pct                                        0.461431
# B_avg_opp_SIG_STR_pct                                    0.504418
# B_avg_TD_pct                                            0.0357556
# B_avg_opp_TD_pct                                         0.143079
# B_avg_SUB_ATT                                            0.578613
# B_avg_opp_SUB_ATT                                       0.0357666
# B_avg_REV                                                0.516602
# B_avg_opp_REV                                          0.00585938
# B_avg_SIG_STR_att                                         152.423
# B_avg_SIG_STR_landed                                      71.6887
# B_avg_opp_SIG_STR_att                                     114.897
# B_avg_opp_SIG_STR_landed                                  51.8739
# B_avg_TOTAL_STR_att                                       159.759
# B_avg_TOTAL_STR_landed                                    77.7511
# B_avg_opp_TOTAL_STR_att                                   144.732
# B_avg_opp_TOTAL_STR_landed                                80.3203
# B_avg_TD_att                                              1.71472
# B_avg_TD_landed                                         0.0535889
# B_avg_opp_TD_att                                          2.06873
# B_avg_opp_TD_landed                                      0.553589
# B_avg_HEAD_att                                            117.205
# B_avg_HEAD_landed                                         44.5193
# B_avg_opp_HEAD_att                                        75.2134
# B_avg_opp_HEAD_landed                                     20.1802
# B_avg_BODY_att                                            18.2355
# B_avg_BODY_landed                                         12.6625
# B_avg_opp_BODY_att                                        16.1462
# B_avg_opp_BODY_landed                                     12.1897
# B_avg_LEG_att                                             16.9832
# B_avg_LEG_landed                                           14.507
# B_avg_opp_LEG_att                                         23.5375
# B_avg_opp_LEG_landed                                       19.504
# B_avg_DISTANCE_att                                        142.016
# B_avg_DISTANCE_landed                                     62.9839
# B_avg_opp_DISTANCE_att                                    105.356
# B_avg_opp_DISTANCE_landed                                 45.7632
# B_avg_CLINCH_att                                          7.32275
# B_avg_CLINCH_landed                                       5.94055
# B_avg_opp_CLINCH_att                                      3.64673
# B_avg_opp_CLINCH_landed                                   1.59351
# B_avg_GROUND_att                                          3.08459
# B_avg_GROUND_landed                                       2.76428
# B_avg_opp_GROUND_att                                      5.89465
# B_avg_opp_GROUND_landed                                   4.51721
# B_avg_CTRL_time(seconds)                                  33.2982
# B_avg_opp_CTRL_time(seconds)                              236.226
# B_total_time_fought(seconds)                              833.348
# B_total_rounds_fought                                          35
# B_total_title_bouts                                             0
# B_current_win_streak                                            1
# B_current_lose_streak                                           0
# B_longest_win_streak                                            4
# B_wins                                                         10
# B_losses                                                        4
# B_draw                                                          0
# B_win_by_Decision_Majority                                      0
# B_win_by_Decision_Split                                         1
# B_win_by_Decision_Unanimous                                     4
# B_win_by_KO/TKO                                                 2
# B_win_by_Submission                                             3
# B_win_by_TKO_Doctor_Stoppage                                    0
# B_Stance                                                 Orthodox
# B_Height_cms                                                190.5
# B_Reach_cms                                                198.12
# B_Weight_lbs                                                  170
# R_avg_KD                                                      1.5
# R_avg_opp_KD                                                    0
# R_avg_SIG_STR_pct                                          0.5325
# R_avg_opp_SIG_STR_pct                                      0.2375
# R_avg_TD_pct                                                    0
# R_avg_opp_TD_pct                                            0.125
# R_avg_SUB_ATT                                                   0
# R_avg_opp_SUB_ATT                                            0.25
# R_avg_REV                                                       0
# R_avg_opp_REV                                                   0
# R_avg_SIG_STR_att                                           59.25
# R_avg_SIG_STR_landed                                        31.75
# R_avg_opp_SIG_STR_att                                       39.75
# R_avg_opp_SIG_STR_landed                                     10.5
# R_avg_TOTAL_STR_att                                         63.25
# R_avg_TOTAL_STR_landed                                      35.75
# R_avg_opp_TOTAL_STR_att                                     39.75
# R_avg_opp_TOTAL_STR_landed                                   10.5
# R_avg_TD_att                                                    0
# R_avg_TD_landed                                                 0
# R_avg_opp_TD_att                                                1
# R_avg_opp_TD_landed                                          0.25
# R_avg_HEAD_att                                              45.75
# R_avg_HEAD_landed                                           23.75
# R_avg_opp_HEAD_att                                          31.75
# R_avg_opp_HEAD_landed                                         5.5
# R_avg_BODY_att                                                 12
# R_avg_BODY_landed                                             7.5
# R_avg_opp_BODY_att                                              5
# R_avg_opp_BODY_landed                                        2.25
# R_avg_LEG_att                                                 1.5
# R_avg_LEG_landed                                              0.5
# R_avg_opp_LEG_att                                               3
# R_avg_opp_LEG_landed                                         2.75
# R_avg_DISTANCE_att                                          51.75
# R_avg_DISTANCE_landed                                       26.25
# R_avg_opp_DISTANCE_att                                      39.25
# R_avg_opp_DISTANCE_landed                                      10
# R_avg_CLINCH_att                                             1.75
# R_avg_CLINCH_landed                                          1.75
# R_avg_opp_CLINCH_att                                          0.5
# R_avg_opp_CLINCH_landed                                       0.5
# R_avg_GROUND_att                                             5.75
# R_avg_GROUND_landed                                          3.75
# R_avg_opp_GROUND_att                                            0
# R_avg_opp_GROUND_landed                                         0
# R_avg_CTRL_time(seconds)                                       18
# R_avg_opp_CTRL_time(seconds)                                13.75
# R_total_time_fought(seconds)                               184.75
# R_total_rounds_fought                                           3
# R_total_title_bouts                                             0
# R_current_win_streak                                            3
# R_current_lose_streak                                           0
# R_longest_win_streak                                            3
# R_wins                                                          3
# R_losses                                                        0
# R_draw                                                          0
# R_win_by_Decision_Majority                                      0
# R_win_by_Decision_Split                                         0
# R_win_by_Decision_Unanimous                                     0
# R_win_by_KO/TKO                                                 3
# R_win_by_Submission                                             0
# R_win_by_TKO_Doctor_Stoppage                                    0
# R_Stance                                                   Switch
# R_Height_cms                                               180.34
# R_Reach_cms                                                185.42
# R_Weight_lbs                                                  170
# B_age                                                          32
# R_age                                                          26
#
#                                                              1     \
# R_fighter                                             Tyson Pedro
# B_fighter                                      Modestas Bukauskas
# Referee                                            Steve Perceval
# date                                                   2023-02-11
# location                      Perth, Western Australia, Australia
# Winner                                                       Blue
# title_bout                                                  False
# weight_class                                    Light Heavyweight
# no_of_rounds                                                    3
# B_avg_KD                                                        0
# B_avg_opp_KD                                                 0.75
# B_avg_SIG_STR_pct                                         0.41125
# B_avg_opp_SIG_STR_pct                                      0.4675
# B_avg_TD_pct                                                    0
# B_avg_opp_TD_pct                                                0
# B_avg_SUB_ATT                                                   0
# B_avg_opp_SUB_ATT                                               0
# B_avg_REV                                                       0
# B_avg_opp_REV                                                   0
# B_avg_SIG_STR_att                                            74.5
# B_avg_SIG_STR_landed                                       29.125
# B_avg_opp_SIG_STR_att                                       85.25
# B_avg_opp_SIG_STR_landed                                       38
# B_avg_TOTAL_STR_att                                         75.75
# B_avg_TOTAL_STR_landed                                     30.125
# B_avg_opp_TOTAL_STR_att                                    90.875
# B_avg_opp_TOTAL_STR_landed                                 43.375
# B_avg_TD_att                                                 0.25
# B_avg_TD_landed                                                 0
# B_avg_opp_TD_att                                             0.75
# B_avg_opp_TD_landed                                             0
# B_avg_HEAD_att                                             64.875
# B_avg_HEAD_landed                                          21.625
# B_avg_opp_HEAD_att                                          63.75
# B_avg_opp_HEAD_landed                                        18.5
# B_avg_BODY_att                                              7.875
# B_avg_BODY_landed                                            5.75
# B_avg_opp_BODY_att                                          12.75
# B_avg_opp_BODY_landed                                          11
# B_avg_LEG_att                                                1.75
# B_avg_LEG_landed                                             1.75
# B_avg_opp_LEG_att                                            8.75
# B_avg_opp_LEG_landed                                          8.5
# B_avg_DISTANCE_att                                         71.125
# B_avg_DISTANCE_landed                                          27
# B_avg_opp_DISTANCE_att                                         84
# B_avg_opp_DISTANCE_landed                                  36.875
# B_avg_CLINCH_att                                            3.375
# B_avg_CLINCH_landed                                         2.125
# B_avg_opp_CLINCH_att                                            1
# B_avg_opp_CLINCH_landed                                     0.875
# B_avg_GROUND_att                                                0
# B_avg_GROUND_landed                                             0
# B_avg_opp_GROUND_att                                         0.25
# B_avg_opp_GROUND_landed                                      0.25
# B_avg_CTRL_time(seconds)                                        1
# B_avg_opp_CTRL_time(seconds)                                 21.5
# B_total_time_fought(seconds)                              502.625
# B_total_rounds_fought                                           7
# B_total_title_bouts                                             0
# B_current_win_streak                                            1
# B_current_lose_streak                                           0
# B_longest_win_streak                                            1
# B_wins                                                          1
# B_losses                                                        3
# B_draw                                                          0
# B_win_by_Decision_Majority                                      0
# B_win_by_Decision_Split                                         0
# B_win_by_Decision_Unanimous                                     0
# B_win_by_KO/TKO                                                 1
# B_win_by_Submission                                             0
# B_win_by_TKO_Doctor_Stoppage                                    0
# B_Stance                                                   Switch
# B_Height_cms                                                190.5
# B_Reach_cms                                                198.12
# B_Weight_lbs                                                  205
# R_avg_KD                                                 0.820312
# R_avg_opp_KD                                             0.132812
# R_avg_SIG_STR_pct                                        0.626563
# R_avg_opp_SIG_STR_pct                                    0.424531
# R_avg_TD_pct                                            0.0078125
# R_avg_opp_TD_pct                                              0.1
# R_avg_SUB_ATT                                            0.226562
# R_avg_opp_SUB_ATT                                          0.0625
# R_avg_REV                                                       0
# R_avg_opp_REV                                                   0
# R_avg_SIG_STR_att                                         20.8906
# R_avg_SIG_STR_landed                                      14.0078
# R_avg_opp_SIG_STR_att                                     17.4141
# R_avg_opp_SIG_STR_landed                                  7.24219
# R_avg_TOTAL_STR_att                                       22.1484
# R_avg_TOTAL_STR_landed                                    15.2266
# R_avg_opp_TOTAL_STR_att                                   23.0703
# R_avg_opp_TOTAL_STR_landed                                12.1016
# R_avg_TD_att                                             0.421875
# R_avg_TD_landed                                          0.015625
# R_avg_opp_TD_att                                         0.945312
# R_avg_opp_TD_landed                                           0.5
# R_avg_HEAD_att                                            14.8906
# R_avg_HEAD_landed                                         8.45312
# R_avg_opp_HEAD_att                                        14.1094
# R_avg_opp_HEAD_landed                                     4.50781
# R_avg_BODY_att                                            3.53906
# R_avg_BODY_landed                                         3.28125
# R_avg_opp_BODY_att                                       0.984375
# R_avg_opp_BODY_landed                                    0.789062
# R_avg_LEG_att                                             2.46094
# R_avg_LEG_landed                                          2.27344
# R_avg_opp_LEG_att                                         2.32031
# R_avg_opp_LEG_landed                                      1.94531
# R_avg_DISTANCE_att                                        15.7344
# R_avg_DISTANCE_landed                                     10.4531
# R_avg_opp_DISTANCE_att                                    12.2031
# R_avg_opp_DISTANCE_landed                                 4.13281
# R_avg_CLINCH_att                                          2.28906
# R_avg_CLINCH_landed                                        1.9375
# R_avg_opp_CLINCH_att                                      0.84375
# R_avg_opp_CLINCH_landed                                   0.34375
# R_avg_GROUND_att                                          2.86719
# R_avg_GROUND_landed                                       1.61719
# R_avg_opp_GROUND_att                                      4.36719
# R_avg_opp_GROUND_landed                                   2.76562
# R_avg_CTRL_time(seconds)                                  14.8594
# R_avg_opp_CTRL_time(seconds)                              51.2969
# R_total_time_fought(seconds)                              222.758
# R_total_rounds_fought                                          12
# R_total_title_bouts                                             0
# R_current_win_streak                                            2
# R_current_lose_streak                                           0
# R_longest_win_streak                                            2
# R_wins                                                          5
# R_losses                                                        3
# R_draw                                                          0
# R_win_by_Decision_Majority                                      0
# R_win_by_Decision_Split                                         0
# R_win_by_Decision_Unanimous                                     0
# R_win_by_KO/TKO                                                 3
# R_win_by_Submission                                             2
# R_win_by_TKO_Doctor_Stoppage                                    0
# R_Stance                                                 Orthodox
# R_Height_cms                                                190.5
# R_Reach_cms                                                200.66
# R_Weight_lbs                                                  205
# B_age                                                          29
# R_age                                                          31
#
#                                                              2     \
# R_fighter                                            Shannon Ross
# B_fighter                                      Kleydson Rodrigues
# Referee                                                Matt Wynne
# date                                                   2023-02-11
# location                      Perth, Western Australia, Australia
# Winner                                                       Blue
# title_bout                                                  False
# weight_class                                            Flyweight
# no_of_rounds                                                    3
# B_avg_KD                                                        0
# B_avg_opp_KD                                                    0
# B_avg_SIG_STR_pct                                            0.56
# B_avg_opp_SIG_STR_pct                                        0.55
# B_avg_TD_pct                                                 0.28
# B_avg_opp_TD_pct                                                0
# B_avg_SUB_ATT                                                   1
# B_avg_opp_SUB_ATT                                               0
# B_avg_REV                                                       2
# B_avg_opp_REV                                                   0
# B_avg_SIG_STR_att                                             143
# B_avg_SIG_STR_landed                                           81
# B_avg_opp_SIG_STR_att                                         127
# B_avg_opp_SIG_STR_landed                                       71
# B_avg_TOTAL_STR_att                                           156
# B_avg_TOTAL_STR_landed                                         93
# B_avg_opp_TOTAL_STR_att                                       221
# B_avg_opp_TOTAL_STR_landed                                    155
# B_avg_TD_att                                                    7
# B_avg_TD_landed                                                 2
# B_avg_opp_TD_att                                                0
# B_avg_opp_TD_landed                                             0
# B_avg_HEAD_att                                                 91
# B_avg_HEAD_landed                                              39
# B_avg_opp_HEAD_att                                             89
# B_avg_opp_HEAD_landed                                          42
# B_avg_BODY_att                                                 40
# B_avg_BODY_landed                                              32
# B_avg_opp_BODY_att                                             25
# B_avg_opp_BODY_landed                                          18
# B_avg_LEG_att                                                  12
# B_avg_LEG_landed                                               10
# B_avg_opp_LEG_att                                              13
# B_avg_opp_LEG_landed                                           11
# B_avg_DISTANCE_att                                            131
# B_avg_DISTANCE_landed                                          70
# B_avg_opp_DISTANCE_att                                         92
# B_avg_opp_DISTANCE_landed                                      45
# B_avg_CLINCH_att                                                7
# B_avg_CLINCH_landed                                             6
# B_avg_opp_CLINCH_att                                           10
# B_avg_opp_CLINCH_landed                                         7
# B_avg_GROUND_att                                                5
# B_avg_GROUND_landed                                             5
# B_avg_opp_GROUND_att                                           25
# B_avg_opp_GROUND_landed                                        19
# B_avg_CTRL_time(seconds)                                      194
# B_avg_opp_CTRL_time(seconds)                                  260
# B_total_time_fought(seconds)                                  900
# B_total_rounds_fought                                           3
# B_total_title_bouts                                             0
# B_current_win_streak                                            0
# B_current_lose_streak                                           1
# B_longest_win_streak                                            0
# B_wins                                                          0
# B_losses                                                        1
# B_draw                                                          0
# B_win_by_Decision_Majority                                      0
# B_win_by_Decision_Split                                         0
# B_win_by_Decision_Unanimous                                     0
# B_win_by_KO/TKO                                                 0
# B_win_by_Submission                                             0
# B_win_by_TKO_Doctor_Stoppage                                    0
# B_Stance                                                 Orthodox
# B_Height_cms                                                165.1
# B_Reach_cms                                                170.18
# B_Weight_lbs                                                  125
# R_avg_KD                                                      NaN
# R_avg_opp_KD                                                  NaN
# R_avg_SIG_STR_pct                                             NaN
# R_avg_opp_SIG_STR_pct                                         NaN
# R_avg_TD_pct                                                  NaN
# R_avg_opp_TD_pct                                              NaN
# R_avg_SUB_ATT                                                 NaN
# R_avg_opp_SUB_ATT                                             NaN
# R_avg_REV                                                     NaN
# R_avg_opp_REV                                                 NaN
# R_avg_SIG_STR_att                                             NaN
# R_avg_SIG_STR_landed                                          NaN
# R_avg_opp_SIG_STR_att                                         NaN
# R_avg_opp_SIG_STR_landed                                      NaN
# R_avg_TOTAL_STR_att                                           NaN
# R_avg_TOTAL_STR_landed                                        NaN
# R_avg_opp_TOTAL_STR_att                                       NaN
# R_avg_opp_TOTAL_STR_landed                                    NaN
# R_avg_TD_att                                                  NaN
# R_avg_TD_landed                                               NaN
# R_avg_opp_TD_att                                              NaN
# R_avg_opp_TD_landed                                           NaN
# R_avg_HEAD_att                                                NaN
# R_avg_HEAD_landed                                             NaN
# R_avg_opp_HEAD_att                                            NaN
# R_avg_opp_HEAD_landed                                         NaN
# R_avg_BODY_att                                                NaN
# R_avg_BODY_landed                                             NaN
# R_avg_opp_BODY_att                                            NaN
# R_avg_opp_BODY_landed                                         NaN
# R_avg_LEG_att                                                 NaN
# R_avg_LEG_landed                                              NaN
# R_avg_opp_LEG_att                                             NaN
# R_avg_opp_LEG_landed                                          NaN
# R_avg_DISTANCE_att                                            NaN
# R_avg_DISTANCE_landed                                         NaN
# R_avg_opp_DISTANCE_att                                        NaN
# R_avg_opp_DISTANCE_landed                                     NaN
# R_avg_CLINCH_att                                              NaN
# R_avg_CLINCH_landed                                           NaN
# R_avg_opp_CLINCH_att                                          NaN
# R_avg_opp_CLINCH_landed                                       NaN
# R_avg_GROUND_att                                              NaN
# R_avg_GROUND_landed                                           NaN
# R_avg_opp_GROUND_att                                          NaN
# R_avg_opp_GROUND_landed                                       NaN
# R_avg_CTRL_time(seconds)                                      NaN
# R_avg_opp_CTRL_time(seconds)                                  NaN
# R_total_time_fought(seconds)                                  NaN
# R_total_rounds_fought                                           0
# R_total_title_bouts                                             0
# R_current_win_streak                                            0
# R_current_lose_streak                                           0
# R_longest_win_streak                                            0
# R_wins                                                          0
# R_losses                                                        0
# R_draw                                                          0
# R_win_by_Decision_Majority                                      0
# R_win_by_Decision_Split                                         0
# R_win_by_Decision_Unanimous                                     0
# R_win_by_KO/TKO                                                 0
# R_win_by_Submission                                             0
# R_win_by_TKO_Doctor_Stoppage                                    0
# R_Stance                                                   Switch
# R_Height_cms                                               167.64
# R_Reach_cms                                                167.64
# R_Weight_lbs                                                  125
# B_age                                                          27
# R_age                                                          33
#
#                                                              3     \
# R_fighter                                             Justin Tafa
# B_fighter                                           Parker Porter
# Referee                                              Jason Herzog
# date                                                   2023-02-11
# location                      Perth, Western Australia, Australia
# Winner                                                        Red
# title_bout                                                  False
# weight_class                                          Heavyweight
# no_of_rounds                                                    3
# B_avg_KD                                                        0
# B_avg_opp_KD                                                0.125
# B_avg_SIG_STR_pct                                        0.220625
# B_avg_opp_SIG_STR_pct                                       0.515
# B_avg_TD_pct                                              0.10875
# B_avg_opp_TD_pct                                             0.25
# B_avg_SUB_ATT                                              0.0625
# B_avg_opp_SUB_ATT                                             0.5
# B_avg_REV                                                       0
# B_avg_opp_REV                                                   0
# B_avg_SIG_STR_att                                           78.75
# B_avg_SIG_STR_landed                                      38.3125
# B_avg_opp_SIG_STR_att                                     92.6875
# B_avg_opp_SIG_STR_landed                                  46.8125
# B_avg_TOTAL_STR_att                                         94.75
# B_avg_TOTAL_STR_landed                                      51.75
# B_avg_opp_TOTAL_STR_att                                   107.875
# B_avg_opp_TOTAL_STR_landed                                 58.875
# B_avg_TD_att                                                 3.25
# B_avg_TD_landed                                              0.75
# B_avg_opp_TD_att                                                1
# B_avg_opp_TD_landed                                           0.5
# B_avg_HEAD_att                                                 65
# B_avg_HEAD_landed                                          25.875
# B_avg_opp_HEAD_att                                          78.25
# B_avg_opp_HEAD_landed                                      33.625
# B_avg_BODY_att                                                4.5
# B_avg_BODY_landed                                          4.1875
# B_avg_opp_BODY_att                                              9
# B_avg_opp_BODY_landed                                      8.0625
# B_avg_LEG_att                                                9.25
# B_avg_LEG_landed                                             8.25
# B_avg_opp_LEG_att                                          5.4375
# B_avg_opp_LEG_landed                                        5.125
# B_avg_DISTANCE_att                                        72.5625
# B_avg_DISTANCE_landed                                     33.5625
# B_avg_opp_DISTANCE_att                                     71.625
# B_avg_opp_DISTANCE_landed                                   34.75
# B_avg_CLINCH_att                                            4.625
# B_avg_CLINCH_landed                                        3.8125
# B_avg_opp_CLINCH_att                                       4.4375
# B_avg_opp_CLINCH_landed                                    3.4375
# B_avg_GROUND_att                                           1.5625
# B_avg_GROUND_landed                                        0.9375
# B_avg_opp_GROUND_att                                       16.625
# B_avg_opp_GROUND_landed                                     8.625
# B_avg_CTRL_time(seconds)                                  132.562
# B_avg_opp_CTRL_time(seconds)                              144.438
# B_total_time_fought(seconds)                                  548
# B_total_rounds_fought                                          11
# B_total_title_bouts                                             0
# B_current_win_streak                                            0
# B_current_lose_streak                                           1
# B_longest_win_streak                                            3
# B_wins                                                          3
# B_losses                                                        2
# B_draw                                                          0
# B_win_by_Decision_Majority                                      0
# B_win_by_Decision_Split                                         0
# B_win_by_Decision_Unanimous                                     3
# B_win_by_KO/TKO                                                 0
# B_win_by_Submission                                             0
# B_win_by_TKO_Doctor_Stoppage                                    0
# B_Stance                                                 Orthodox
# B_Height_cms                                               182.88
# B_Reach_cms                                                 190.5
# B_Weight_lbs                                                  265
# R_avg_KD                                                   0.5625
# R_avg_opp_KD                                               0.0625
# R_avg_SIG_STR_pct                                            0.53
# R_avg_opp_SIG_STR_pct                                      0.5225
# R_avg_TD_pct                                                    0
# R_avg_opp_TD_pct                                                0
# R_avg_SUB_ATT                                                   0
# R_avg_opp_SUB_ATT                                             0.5
# R_avg_REV                                                       0
# R_avg_opp_REV                                                   0
# R_avg_SIG_STR_att                                           61.75
# R_avg_SIG_STR_landed                                        32.75
# R_avg_opp_SIG_STR_att                                     85.6875
# R_avg_opp_SIG_STR_landed                                  43.0625
# R_avg_TOTAL_STR_att                                       65.3125
# R_avg_TOTAL_STR_landed                                    36.3125
# R_avg_opp_TOTAL_STR_att                                   91.0625
# R_avg_opp_TOTAL_STR_landed                                48.1875
# R_avg_TD_att                                                 0.25
# R_avg_TD_landed                                                 0
# R_avg_opp_TD_att                                            0.625
# R_avg_opp_TD_landed                                             0
# R_avg_HEAD_att                                            44.4375
# R_avg_HEAD_landed                                          17.625
# R_avg_opp_HEAD_att                                           61.5
# R_avg_opp_HEAD_landed                                     23.0625
# R_avg_BODY_att                                             13.125
# R_avg_BODY_landed                                         11.0625
# R_avg_opp_BODY_att                                         16.125
# R_avg_opp_BODY_landed                                       12.75
# R_avg_LEG_att                                              4.1875
# R_avg_LEG_landed                                           4.0625
# R_avg_opp_LEG_att                                          8.0625
# R_avg_opp_LEG_landed                                         7.25
# R_avg_DISTANCE_att                                          57.25
# R_avg_DISTANCE_landed                                      29.375
# R_avg_opp_DISTANCE_att                                    78.1875
# R_avg_opp_DISTANCE_landed                                 37.1875
# R_avg_CLINCH_att                                           3.3125
# R_avg_CLINCH_landed                                        2.8125
# R_avg_opp_CLINCH_att                                          7.5
# R_avg_opp_CLINCH_landed                                     5.875
# R_avg_GROUND_att                                           1.1875
# R_avg_GROUND_landed                                        0.5625
# R_avg_opp_GROUND_att                                            0
# R_avg_opp_GROUND_landed                                         0
# R_avg_CTRL_time(seconds)                                  52.3125
# R_avg_opp_CTRL_time(seconds)                               11.875
# R_total_time_fought(seconds)                              409.562
# R_total_rounds_fought                                           9
# R_total_title_bouts                                             0
# R_current_win_streak                                            0
# R_current_lose_streak                                           1
# R_longest_win_streak                                            1
# R_wins                                                          2
# R_losses                                                        3
# R_draw                                                          0
# R_win_by_Decision_Majority                                      0
# R_win_by_Decision_Split                                         0
# R_win_by_Decision_Unanimous                                     0
# R_win_by_KO/TKO                                                 2
# R_win_by_Submission                                             0
# R_win_by_TKO_Doctor_Stoppage                                    0
# R_Stance                                                 Southpaw
# R_Height_cms                                               182.88
# R_Reach_cms                                                187.96
# R_Weight_lbs                                                  264
# B_age                                                          37
# R_age                                                          29
#
#                                                              4     \
# R_fighter                                            Josh Culibao
# B_fighter                                     Melsik Baghdasaryan
# Referee                                            Peter Hickmott
# date                                                   2023-02-11
# location                      Perth, Western Australia, Australia
# Winner                                                        Red
# title_bout                                                  False
# weight_class                                        Featherweight
# no_of_rounds                                                    3
# B_avg_KD                                                      0.5
# B_avg_opp_KD                                                    0
# B_avg_SIG_STR_pct                                            0.59
# B_avg_opp_SIG_STR_pct                                       0.465
# B_avg_TD_pct                                                    0
# B_avg_opp_TD_pct                                              0.5
# B_avg_SUB_ATT                                                   0
# B_avg_opp_SUB_ATT                                               0
# B_avg_REV                                                       0
# B_avg_opp_REV                                                   0
# B_avg_SIG_STR_att                                            99.5
# B_avg_SIG_STR_landed                                         59.5
# B_avg_opp_SIG_STR_att                                          77
# B_avg_opp_SIG_STR_landed                                     35.5
# B_avg_TOTAL_STR_att                                           104
# B_avg_TOTAL_STR_landed                                         64
# B_avg_opp_TOTAL_STR_att                                      80.5
# B_avg_opp_TOTAL_STR_landed                                   37.5
# B_avg_TD_att                                                    0
# B_avg_TD_landed                                                 0
# B_avg_opp_TD_att                                              2.5
# B_avg_opp_TD_landed                                           0.5
# B_avg_HEAD_att                                               57.5
# B_avg_HEAD_landed                                              27
# B_avg_opp_HEAD_att                                             52
# B_avg_opp_HEAD_landed                                        20.5
# B_avg_BODY_att                                               23.5
# B_avg_BODY_landed                                            18.5
# B_avg_opp_BODY_att                                           19.5
# B_avg_opp_BODY_landed                                          11
# B_avg_LEG_att                                                18.5
# B_avg_LEG_landed                                               14
# B_avg_opp_LEG_att                                             5.5
# B_avg_opp_LEG_landed                                            4
# B_avg_DISTANCE_att                                           89.5
# B_avg_DISTANCE_landed                                          50
# B_avg_opp_DISTANCE_att                                       69.5
# B_avg_opp_DISTANCE_landed                                      30
# B_avg_CLINCH_att                                              8.5
# B_avg_CLINCH_landed                                           8.5
# B_avg_opp_CLINCH_att                                          7.5
# B_avg_opp_CLINCH_landed                                       5.5
# B_avg_GROUND_att                                              1.5
# B_avg_GROUND_landed                                             1
# B_avg_opp_GROUND_att                                            0
# B_avg_opp_GROUND_landed                                         0
# B_avg_CTRL_time(seconds)                                     40.5
# B_avg_opp_CTRL_time(seconds)                                 31.5
# B_total_time_fought(seconds)                                  655
# B_total_rounds_fought                                           5
# B_total_title_bouts                                             0
# B_current_win_streak                                            2
# B_current_lose_streak                                           0
# B_longest_win_streak                                            2
# B_wins                                                          2
# B_losses                                                        0
# B_draw                                                          0
# B_win_by_Decision_Majority                                      0
# B_win_by_Decision_Split                                         0
# B_win_by_Decision_Unanimous                                     1
# B_win_by_KO/TKO                                                 1
# B_win_by_Submission                                             0
# B_win_by_TKO_Doctor_Stoppage                                    0
# B_Stance                                                 Southpaw
# B_Height_cms                                               175.26
# B_Reach_cms                                                 177.8
# B_Weight_lbs                                                  145
# R_avg_KD                                                    1.125
# R_avg_opp_KD                                                    0
# R_avg_SIG_STR_pct                                         0.44875
# R_avg_opp_SIG_STR_pct                                     0.33375
# R_avg_TD_pct                                                    0
# R_avg_opp_TD_pct                                            0.285
# R_avg_SUB_ATT                                                0.25
# R_avg_opp_SUB_ATT                                            0.75
# R_avg_REV                                                       0
# R_avg_opp_REV                                                   0
# R_avg_SIG_STR_att                                           100.5
# R_avg_SIG_STR_landed                                           46
# R_avg_opp_SIG_STR_att                                      121.25
# R_avg_opp_SIG_STR_landed                                   39.625
# R_avg_TOTAL_STR_att                                           121
# R_avg_TOTAL_STR_landed                                     64.125
# R_avg_opp_TOTAL_STR_att                                   141.625
# R_avg_opp_TOTAL_STR_landed                                   57.5
# R_avg_TD_att                                                  1.5
# R_avg_TD_landed                                                 0
# R_avg_opp_TD_att                                            4.625
# R_avg_opp_TD_landed                                             1
# R_avg_HEAD_att                                             81.375
# R_avg_HEAD_landed                                           31.75
# R_avg_opp_HEAD_att                                          98.25
# R_avg_opp_HEAD_landed                                      24.625
# R_avg_BODY_att                                               10.5
# R_avg_BODY_landed                                               7
# R_avg_opp_BODY_att                                           13.5
# R_avg_opp_BODY_landed                                       7.125
# R_avg_LEG_att                                               8.625
# R_avg_LEG_landed                                             7.25
# R_avg_opp_LEG_att                                             9.5
# R_avg_opp_LEG_landed                                        7.875
# ...
# R_avg_opp_REV                                   NaN                    NaN
# R_avg_SIG_STR_att                               NaN                    NaN
# R_avg_SIG_STR_landed                            NaN                    NaN
# R_avg_opp_SIG_STR_att                           NaN                    NaN
# R_avg_opp_SIG_STR_landed                        NaN                    NaN
# R_avg_TOTAL_STR_att                             NaN                    NaN
# R_avg_TOTAL_STR_landed                          NaN                    NaN
# R_avg_opp_TOTAL_STR_att                         NaN                    NaN
# R_avg_opp_TOTAL_STR_landed                      NaN                    NaN
# R_avg_TD_att                                    NaN                    NaN
# R_avg_TD_landed                                 NaN                    NaN
# R_avg_opp_TD_att                                NaN                    NaN
# R_avg_opp_TD_landed                             NaN                    NaN
# R_avg_HEAD_att                                  NaN                    NaN
# R_avg_HEAD_landed                               NaN                    NaN
# R_avg_opp_HEAD_att                              NaN                    NaN
# R_avg_opp_HEAD_landed                           NaN                    NaN
# R_avg_BODY_att                                  NaN                    NaN
# R_avg_BODY_landed                               NaN                    NaN
# R_avg_opp_BODY_att                              NaN                    NaN
# R_avg_opp_BODY_landed                           NaN                    NaN
# R_avg_LEG_att                                   NaN                    NaN
# R_avg_LEG_landed                                NaN                    NaN
# R_avg_opp_LEG_att                               NaN                    NaN
# R_avg_opp_LEG_landed                            NaN                    NaN
# R_avg_DISTANCE_att                              NaN                    NaN
# R_avg_DISTANCE_landed                           NaN                    NaN
# R_avg_opp_DISTANCE_att                          NaN                    NaN
# R_avg_opp_DISTANCE_landed                       NaN                    NaN
# R_avg_CLINCH_att                                NaN                    NaN
# R_avg_CLINCH_landed                             NaN                    NaN
# R_avg_opp_CLINCH_att                            NaN                    NaN
# R_avg_opp_CLINCH_landed                         NaN                    NaN
# R_avg_GROUND_att                                NaN                    NaN
# R_avg_GROUND_landed                             NaN                    NaN
# R_avg_opp_GROUND_att                            NaN                    NaN
# R_avg_opp_GROUND_landed                         NaN                    NaN
# R_avg_CTRL_time(seconds)                        NaN                    NaN
# R_avg_opp_CTRL_time(seconds)                    NaN                    NaN
# R_total_time_fought(seconds)                    NaN                    NaN
# R_total_rounds_fought                             0                      0
# R_total_title_bouts                               0                      0
# R_current_win_streak                              0                      0
# R_current_lose_streak                             0                      0
# R_longest_win_streak                              0                      0
# R_wins                                            0                      0
# R_losses                                          0                      0
# R_draw                                            0                      0
# R_win_by_Decision_Majority                        0                      0
# R_win_by_Decision_Split                           0                      0
# R_win_by_Decision_Unanimous                       0                      0
# R_win_by_KO/TKO                                   0                      0
# R_win_by_Submission                               0                      0
# R_win_by_TKO_Doctor_Stoppage                      0                      0
# R_Stance                                   Southpaw                    NaN
# R_Height_cms                                  190.5                    NaN
# R_Reach_cms                                     NaN                    NaN
# R_Weight_lbs                                    260                    NaN
# B_age                                           NaN                    NaN
# R_age                                           NaN                    NaN
#
#                                                6964                   6965
# R_fighter                              Scott Morris          Patrick Smith
# B_fighter                            Sean Daugherty             Ray Wizard
# Referee                               John McCarthy          John McCarthy
# date                                     1994-03-11             1994-03-11
# location                      Denver, Colorado, USA  Denver, Colorado, USA
# Winner                                          Red                    Red
# title_bout                                    False                  False
# weight_class                            Open Weight            Open Weight
# no_of_rounds                                      1                      1
# B_avg_KD                                        NaN                    NaN
# B_avg_opp_KD                                    NaN                    NaN
# B_avg_SIG_STR_pct                               NaN                    NaN
# B_avg_opp_SIG_STR_pct                           NaN                    NaN
# B_avg_TD_pct                                    NaN                    NaN
# B_avg_opp_TD_pct                                NaN                    NaN
# B_avg_SUB_ATT                                   NaN                    NaN
# B_avg_opp_SUB_ATT                               NaN                    NaN
# B_avg_REV                                       NaN                    NaN
# B_avg_opp_REV                                   NaN                    NaN
# B_avg_SIG_STR_att                               NaN                    NaN
# B_avg_SIG_STR_landed                            NaN                    NaN
# B_avg_opp_SIG_STR_att                           NaN                    NaN
# B_avg_opp_SIG_STR_landed                        NaN                    NaN
# B_avg_TOTAL_STR_att                             NaN                    NaN
# B_avg_TOTAL_STR_landed                          NaN                    NaN
# B_avg_opp_TOTAL_STR_att                         NaN                    NaN
# B_avg_opp_TOTAL_STR_landed                      NaN                    NaN
# B_avg_TD_att                                    NaN                    NaN
# B_avg_TD_landed                                 NaN                    NaN
# B_avg_opp_TD_att                                NaN                    NaN
# B_avg_opp_TD_landed                             NaN                    NaN
# B_avg_HEAD_att                                  NaN                    NaN
# B_avg_HEAD_landed                               NaN                    NaN
# B_avg_opp_HEAD_att                              NaN                    NaN
# B_avg_opp_HEAD_landed                           NaN                    NaN
# B_avg_BODY_att                                  NaN                    NaN
# B_avg_BODY_landed                               NaN                    NaN
# B_avg_opp_BODY_att                              NaN                    NaN
# B_avg_opp_BODY_landed                           NaN                    NaN
# B_avg_LEG_att                                   NaN                    NaN
# B_avg_LEG_landed                                NaN                    NaN
# B_avg_opp_LEG_att                               NaN                    NaN
# B_avg_opp_LEG_landed                            NaN                    NaN
# B_avg_DISTANCE_att                              NaN                    NaN
# B_avg_DISTANCE_landed                           NaN                    NaN
# B_avg_opp_DISTANCE_att                          NaN                    NaN
# B_avg_opp_DISTANCE_landed                       NaN                    NaN
# B_avg_CLINCH_att                                NaN                    NaN
# B_avg_CLINCH_landed                             NaN                    NaN
# B_avg_opp_CLINCH_att                            NaN                    NaN
# B_avg_opp_CLINCH_landed                         NaN                    NaN
# B_avg_GROUND_att                                NaN                    NaN
# B_avg_GROUND_landed                             NaN                    NaN
# B_avg_opp_GROUND_att                            NaN                    NaN
# B_avg_opp_GROUND_landed                         NaN                    NaN
# B_avg_CTRL_time(seconds)                        NaN                    NaN
# B_avg_opp_CTRL_time(seconds)                    NaN                    NaN
# B_total_time_fought(seconds)                    NaN                    NaN
# B_total_rounds_fought                             0                      0
# B_total_title_bouts                               0                      0
# B_current_win_streak                              0                      0
# B_current_lose_streak                             0                      0
# B_longest_win_streak                              0                      0
# B_wins                                            0                      0
# B_losses                                          0                      0
# B_draw                                            0                      0
# B_win_by_Decision_Majority                        0                      0
# B_win_by_Decision_Split                           0                      0
# B_win_by_Decision_Unanimous                       0                      0
# B_win_by_KO/TKO                                   0                      0
# B_win_by_Submission                               0                      0
# B_win_by_TKO_Doctor_Stoppage                      0                      0
# B_Stance                                        NaN                    NaN
# B_Height_cms                                 182.88                    NaN
# B_Reach_cms                                     NaN                    NaN
# B_Weight_lbs                                    175                    NaN
# R_avg_KD                                        NaN                    NaN
# R_avg_opp_KD                                    NaN                    NaN
# R_avg_SIG_STR_pct                               NaN                    NaN
# R_avg_opp_SIG_STR_pct                           NaN                    NaN
# R_avg_TD_pct                                    NaN                    NaN
# R_avg_opp_TD_pct                                NaN                    NaN
# R_avg_SUB_ATT                                   NaN                    NaN
# R_avg_opp_SUB_ATT                               NaN                    NaN
# R_avg_REV                                       NaN                    NaN
# R_avg_opp_REV                                   NaN                    NaN
# R_avg_SIG_STR_att                               NaN                    NaN
# R_avg_SIG_STR_landed                            NaN                    NaN
# R_avg_opp_SIG_STR_att                           NaN                    NaN
# R_avg_opp_SIG_STR_landed                        NaN                    NaN
# R_avg_TOTAL_STR_att                             NaN                    NaN
# R_avg_TOTAL_STR_landed                          NaN                    NaN
# R_avg_opp_TOTAL_STR_att                         NaN                    NaN
# R_avg_opp_TOTAL_STR_landed                      NaN                    NaN
# R_avg_TD_att                                    NaN                    NaN
# R_avg_TD_landed                                 NaN                    NaN
# R_avg_opp_TD_att                                NaN                    NaN
# R_avg_opp_TD_landed                             NaN                    NaN
# R_avg_HEAD_att                                  NaN                    NaN
# R_avg_HEAD_landed                               NaN                    NaN
# R_avg_opp_HEAD_att                              NaN                    NaN
# R_avg_opp_HEAD_landed                           NaN                    NaN
# R_avg_BODY_att                                  NaN                    NaN
# R_avg_BODY_landed                               NaN                    NaN
# R_avg_opp_BODY_att                              NaN                    NaN
# R_avg_opp_BODY_landed                           NaN                    NaN
# R_avg_LEG_att                                   NaN                    NaN
# R_avg_LEG_landed                                NaN                    NaN
# R_avg_opp_LEG_att                               NaN                    NaN
# R_avg_opp_LEG_landed                            NaN                    NaN
# R_avg_DISTANCE_att                              NaN                    NaN
# R_avg_DISTANCE_landed                           NaN                    NaN
# R_avg_opp_DISTANCE_att                          NaN                    NaN
# R_avg_opp_DISTANCE_landed                       NaN                    NaN
# R_avg_CLINCH_att                                NaN                    NaN
# R_avg_CLINCH_landed                             NaN                    NaN
# R_avg_opp_CLINCH_att                            NaN                    NaN
# R_avg_opp_CLINCH_landed                         NaN                    NaN
# R_avg_GROUND_att                                NaN                    NaN
# R_avg_GROUND_landed                             NaN                    NaN
# R_avg_opp_GROUND_att                            NaN                    NaN
# R_avg_opp_GROUND_landed                         NaN                    NaN
# R_avg_CTRL_time(seconds)                        NaN                    NaN
# R_avg_opp_CTRL_time(seconds)                    NaN                    NaN
# R_total_time_fought(seconds)                    NaN                    NaN
# R_total_rounds_fought                             0                      0
# R_total_title_bouts                               0                      0
# R_current_win_streak                              0                      0
# R_current_lose_streak                             0                      0
# R_longest_win_streak                              0                      0
# R_wins                                            0                      0
# R_losses                                          0                      0
# R_draw                                            0                      0
# R_win_by_Decision_Majority                        0                      0
# R_win_by_Decision_Split                           0                      0
# R_win_by_Decision_Unanimous                       0                      0
# R_win_by_KO/TKO                                   0                      0
# R_win_by_Submission                               0                      0
# R_win_by_TKO_Doctor_Stoppage                      0                      0
# R_Stance                                   Orthodox               Orthodox
# R_Height_cms                                  177.8                 187.96
# R_Reach_cms                                     NaN                    NaN
# R_Weight_lbs                                    210                    225
# B_age                                            18                    NaN
# R_age                                           NaN                     30
#
# [145 rows x 6966 columns]

# %%
df.describe()
# Out:
#        no_of_rounds     B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# count   6966.000000  5407.000000   5407.000000        5407.000000
# mean       3.143267     0.244123      0.177405           0.458049
# std        0.622274     0.372226      0.327472           0.128405
# min        1.000000     0.000000      0.000000           0.000000
# 25%        3.000000     0.000000      0.000000           0.382012
# 50%        3.000000     0.015625      0.000000           0.455000
# 75%        3.000000     0.500000      0.250000           0.532111
# max        5.000000     5.000000      4.000000           1.000000
#
#        B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  \
# count            5407.000000   5407.000000       5407.000000    5407.000000
# mean                0.441093      0.284549          0.264770       0.452109
# std                 0.130557      0.270008          0.263179       0.698396
# min                 0.000000      0.000000          0.000000       0.000000
# 25%                 0.360000      0.020625          0.033086       0.000000
# 50%                 0.436250      0.240000          0.200000       0.125000
# 75%                 0.516250      0.495000          0.416250       0.656284
# max                 1.000000      1.000000          1.000000       8.000000
#
#        B_avg_opp_SUB_ATT    B_avg_REV  ...  R_win_by_Decision_Split  \
# count        5407.000000  5407.000000  ...              6966.000000
# mean            0.389289     0.151335  ...                 0.328309
# std             0.634417     0.330888  ...                 0.639023
# min             0.000000     0.000000  ...                 0.000000
# 25%             0.000000     0.000000  ...                 0.000000
# 50%             0.064478     0.000000  ...                 0.000000
# 75%             0.500379     0.125000  ...                 1.000000
# max             7.000000     4.000000  ...                 5.000000
#
#        R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# count                  6966.000000      6966.000000          6966.000000
# mean                      1.331898         1.347258             0.815389
# std                       1.772027         1.906312             1.413736
# min                       0.000000         0.000000             0.000000
# 25%                       0.000000         0.000000             0.000000
# 50%                       1.000000         1.000000             0.000000
# 75%                       2.000000         2.000000             1.000000
# max                      11.000000        13.000000            16.000000
#
#        R_win_by_TKO_Doctor_Stoppage  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# count                   6966.000000   6949.000000  6553.000000   6951.000000
# mean                       0.066466    178.770456   183.380403    169.319379
# std                        0.269062      8.921155    10.754752     35.936180
# min                        0.000000    152.400000   147.320000    115.000000
# 25%                        0.000000    172.720000   177.800000    145.000000
# 50%                        0.000000    180.340000   182.880000    170.000000
# 75%                        0.000000    185.420000   190.500000    185.000000
# max                        2.000000    210.820000   213.360000    345.000000
#
#              B_age        R_age
# count  6794.000000  6890.000000
# mean     29.460553    29.820755
# std       4.044539     4.220405
# min      18.000000    18.000000
# 25%      27.000000    27.000000
# 50%      29.000000    30.000000
# 75%      32.000000    33.000000
# max      51.000000    47.000000
#
# [8 rows x 135 columns]

# %% [markdown]
# ## Dealing with NaNs

# %%
for column in df.columns:
    if df[column].isnull().sum()!=0:
        print(f"Nan in {column}: {df[column].isnull().sum()}")
# Out:
# Nan in Referee: 32
# Nan in Winner: 1
# Nan in B_avg_KD: 1559
# Nan in B_avg_opp_KD: 1559
# Nan in B_avg_SIG_STR_pct: 1559
# Nan in B_avg_opp_SIG_STR_pct: 1559
# Nan in B_avg_TD_pct: 1559
# Nan in B_avg_opp_TD_pct: 1559
# Nan in B_avg_SUB_ATT: 1559
# Nan in B_avg_opp_SUB_ATT: 1559
# Nan in B_avg_REV: 1559
# Nan in B_avg_opp_REV: 1559
# Nan in B_avg_SIG_STR_att: 1559
# Nan in B_avg_SIG_STR_landed: 1559
# Nan in B_avg_opp_SIG_STR_att: 1559
# Nan in B_avg_opp_SIG_STR_landed: 1559
# Nan in B_avg_TOTAL_STR_att: 1559
# Nan in B_avg_TOTAL_STR_landed: 1559
# Nan in B_avg_opp_TOTAL_STR_att: 1559
# Nan in B_avg_opp_TOTAL_STR_landed: 1559
# Nan in B_avg_TD_att: 1559
# Nan in B_avg_TD_landed: 1559
# Nan in B_avg_opp_TD_att: 1559
# Nan in B_avg_opp_TD_landed: 1559
# Nan in B_avg_HEAD_att: 1559
# Nan in B_avg_HEAD_landed: 1559
# Nan in B_avg_opp_HEAD_att: 1559
# Nan in B_avg_opp_HEAD_landed: 1559
# Nan in B_avg_BODY_att: 1559
# Nan in B_avg_BODY_landed: 1559
# Nan in B_avg_opp_BODY_att: 1559
# Nan in B_avg_opp_BODY_landed: 1559
# Nan in B_avg_LEG_att: 1559
# Nan in B_avg_LEG_landed: 1559
# Nan in B_avg_opp_LEG_att: 1559
# Nan in B_avg_opp_LEG_landed: 1559
# Nan in B_avg_DISTANCE_att: 1559
# Nan in B_avg_DISTANCE_landed: 1559
# Nan in B_avg_opp_DISTANCE_att: 1559
# Nan in B_avg_opp_DISTANCE_landed: 1559
# Nan in B_avg_CLINCH_att: 1559
# Nan in B_avg_CLINCH_landed: 1559
# Nan in B_avg_opp_CLINCH_att: 1559
# Nan in B_avg_opp_CLINCH_landed: 1559
# Nan in B_avg_GROUND_att: 1559
# Nan in B_avg_GROUND_landed: 1559
# Nan in B_avg_opp_GROUND_att: 1559
# Nan in B_avg_opp_GROUND_landed: 1559
# Nan in B_avg_CTRL_time(seconds): 1559
# Nan in B_avg_opp_CTRL_time(seconds): 1559
# Nan in B_total_time_fought(seconds): 1559
# Nan in B_Stance: 70
# Nan in B_Height_cms: 10
# Nan in B_Reach_cms: 883
# Nan in B_Weight_lbs: 8
# Nan in R_avg_KD: 775
# Nan in R_avg_opp_KD: 775
# Nan in R_avg_SIG_STR_pct: 775
# Nan in R_avg_opp_SIG_STR_pct: 775
# Nan in R_avg_TD_pct: 775
# Nan in R_avg_opp_TD_pct: 775
# Nan in R_avg_SUB_ATT: 775
# Nan in R_avg_opp_SUB_ATT: 775
# Nan in R_avg_REV: 775
# Nan in R_avg_opp_REV: 775
# Nan in R_avg_SIG_STR_att: 775
# Nan in R_avg_SIG_STR_landed: 775
# Nan in R_avg_opp_SIG_STR_att: 775
# Nan in R_avg_opp_SIG_STR_landed: 775
# Nan in R_avg_TOTAL_STR_att: 775
# Nan in R_avg_TOTAL_STR_landed: 775
# Nan in R_avg_opp_TOTAL_STR_att: 775
# Nan in R_avg_opp_TOTAL_STR_landed: 775
# Nan in R_avg_TD_att: 775
# Nan in R_avg_TD_landed: 775
# Nan in R_avg_opp_TD_att: 775
# Nan in R_avg_opp_TD_landed: 775
# Nan in R_avg_HEAD_att: 775
# Nan in R_avg_HEAD_landed: 775
# Nan in R_avg_opp_HEAD_att: 775
# Nan in R_avg_opp_HEAD_landed: 775
# Nan in R_avg_BODY_att: 775
# Nan in R_avg_BODY_landed: 775
# Nan in R_avg_opp_BODY_att: 775
# Nan in R_avg_opp_BODY_landed: 775
# Nan in R_avg_LEG_att: 775
# Nan in R_avg_LEG_landed: 775
# Nan in R_avg_opp_LEG_att: 775
# Nan in R_avg_opp_LEG_landed: 775
# Nan in R_avg_DISTANCE_att: 775
# Nan in R_avg_DISTANCE_landed: 775
# Nan in R_avg_opp_DISTANCE_att: 775
# Nan in R_avg_opp_DISTANCE_landed: 775
# Nan in R_avg_CLINCH_att: 775
# Nan in R_avg_CLINCH_landed: 775
# Nan in R_avg_opp_CLINCH_att: 775
# Nan in R_avg_opp_CLINCH_landed: 775
# Nan in R_avg_GROUND_att: 775
# Nan in R_avg_GROUND_landed: 775
# Nan in R_avg_opp_GROUND_att: 775
# Nan in R_avg_opp_GROUND_landed: 775
# Nan in R_avg_CTRL_time(seconds): 775
# Nan in R_avg_opp_CTRL_time(seconds): 775
# Nan in R_total_time_fought(seconds): 775
# Nan in R_Stance: 40
# Nan in R_Height_cms: 17
# Nan in R_Reach_cms: 413
# Nan in R_Weight_lbs: 15
# Nan in B_age: 172
# Nan in R_age: 76

# %% [markdown]
# * Looks like the blue fighter stats have 1387 missing rows and the red fighter stats have 704 missing rows, i.e those fighters must not have had any previous fights. We should replace these values with the median.

# %%
df2 = df.copy()

# %% [markdown]
# * Referee doesn't look like an important column. Let's delete that.
# * Let's see if height and reach have a correlation
# * The rest i.e. Age, Stance and Height, let's fill with the median of that column.

# %%
df2.drop(columns=['Referee'], inplace=True)

# %%
df2['R_Reach_cms']
# Out:
# 0       185.42
# 1       200.66
# 2       167.64
# 3       187.96
# 4       185.42
#          ...
# 6961       NaN
# 6962       NaN
# 6963       NaN
# 6964       NaN
# 6965       NaN
# Name: R_Reach_cms, Length: 6966, dtype: float64

# %%
# Set style of scatterplot
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

# Create scatterplot of dataframe
sns.lmplot(x='R_Height_cms', # Horizontal axis
           y='R_Reach_cms', # Vertical axis
           data=df2, # Data source
           fit_reg=True # fix a regression line
           ) # S marker size

# %% [markdown]
# * We can see there is a positive correlation between height and reach. So we'll replace reach with height

# %%
df2['R_Reach_cms'].fillna(df2['R_Height_cms'], inplace=True)
df2['B_Reach_cms'].fillna(df2['B_Height_cms'], inplace=True)
df2.fillna(df2.median(), inplace=True)

# %%
df2['B_Stance'].value_counts()
# Out:
# Orthodox       5191
# Southpaw       1350
# Switch          342
# Open Stance       9
# Sideways          4
# Name: B_Stance, dtype: int64

# %%
df2['R_Stance'].value_counts()
# Out:
# Orthodox       5221
# Southpaw       1401
# Switch          287
# Open Stance      15
# Sideways          2
# Name: R_Stance, dtype: int64

# %%
df2['R_Stance'].fillna('Orthodox', inplace=True)
df2['B_Stance'].fillna('Orthodox', inplace=True)

# %%
for column in df2.columns:
    if df2[column].isnull().sum()!=0:
        print(f"Nan in {column}: {df2[column].isnull().sum()}")
# Out:
# Nan in Winner: 1

# %% [markdown]
# ## Removing non essential columns

# %%
df2['location'].value_counts()
# Out:
# Las Vegas, Nevada, USA                         2196
# Abu Dhabi, Abu Dhabi, United Arab Emirates      183
# London, England, United Kingdom                 140
# Houston, Texas, USA                             108
# Anaheim, California, USA                         95
# Newark, New Jersey, USA                          90
# Chicago, Illinois, USA                           81
# Montreal, Quebec, Canada                         81
# Atlantic City, New Jersey, USA                   80
# Los Angeles, California, USA                     79
# Dallas, Texas, USA                               76
# New York City, New York, USA                     74
# Toronto, Ontario, Canada                         74
# Boston, Massachusetts, USA                       72
# Stockholm, Sweden                                72
# Rio de Janeiro, Brazil                           69
# Denver, Colorado, USA                            66
# Rio de Janeiro, Rio de Janeiro, Brazil           65
# Sao Paulo, Sao Paulo, Brazil                     63
# Sacramento, California, USA                      62
# Mexico City, Distrito Federal, Mexico            59
# Nashville, Tennessee, USA                        59
# Jacksonville, Florida, USA                       57
# Sydney, New South Wales, Australia               56
# Vancouver, British Columbia, Canada              56
# Orlando, Florida, USA                            52
# Phoenix, Arizona, USA                            50
# Melbourne, Victoria, Australia                   48
# Kallang, Singapore                               47
# San Jose, California, USA                        47
# Austin, Texas, USA                               47
# Atlanta, Georgia, USA                            45
# Saitama, Japan                                   45
# New Orleans, Louisiana, USA                      45
# Manchester, England, United Kingdom              44
# San Diego, California, USA                       44
# Columbus, Ohio, USA                              41
# Charlotte, North Carolina, USA                   39
# Fortaleza, Ceara, Brazil                         37
# Milwaukee, Wisconsin, USA                        36
# Brasilia, Distrito Federal, Brazil               36
# Philadelphia, Pennsylvania, USA                  35
# Seattle, Washington, USA                         35
# Hollywood, Florida, USA                          35
# Tampa, Florida, USA                              35
# Pittsburgh, Pennsylvania, USA                    34
# Auckland, New Zealand                            33
# Fairfax, Virginia, USA                           33
# Broomfield, Colorado, USA                        33
# Minneapolis, Minnesota, USA                      32
# Uncasville, Connecticut, USA                     32
# Brooklyn, New York, USA                          32
# Birmingham, Alabama, USA                         31
# Dublin, Leinster, Ireland                        30
# Sao Paulo, Brazil                                30
# Glendale, Arizona, USA                           28
# Macau, China                                     27
# Moscow, Moscow, Russia                           25
# Ottawa, Ontario, Canada                          25
# Norfolk, Virginia, USA                           25
# Sunrise, Florida, USA                            25
# Jaragua do Sul, Santa Catarina, Brazil           25
# Perth, Western Australia, Australia              25
# Rotterdam, Zuid-Holland, Netherlands             25
# Adelaide, South Australia, Australia             24
# San Antonio, Texas, USA                          24
# Hamburg, Hamburg, Germany                        24
# Glasgow, Scotland, United Kingdom                24
# Salt Lake City, Utah, USA                        24
# Calgary, Alberta, Canada                         24
# Brisbane, Queensland, Australia                  23
# Indianapolis, Indiana, USA                       23
# Oklahoma City, Oklahoma, USA                     23
# Halifax, Nova Scotia, Canada                     23
# Portland, Oregon, USA                            23
# Goiania, Goias, Brazil                           23
# Barueri, Sao Paulo, Brazil                       22
# Edmonton, Alberta, Canada                        22
# Buffalo, New York, USA                           22
# Belo Horizonte, Minas Gerais, Brazil             22
# Winnipeg, Manitoba, Canada                       22
# Washington, DC, USA                              22
# Cincinnati, Ohio, USA                            22
# Belfast, Northern Ireland, United Kingdom        21
# Birmingham, England, United Kingdom              21
# Detroit, Michigan, USA                           20
# East Rutherford, New Jersey, USA                 20
# Tulsa, Oklahoma, USA                             19
# Omaha, Nebraska, USA                             19
# Abu Dhabi, United Arab Emirates                  18
# Cedar Rapids, Iowa, USA                          16
# Lake Charles, Louisiana, USA                     15
# Augusta, Georgia, USA                            15
# Bay St. Louis, Mississippi, USA                  14
# Montevideo, Uruguay                              13
# Rio Rancho, New Mexico, USA                      13
# Boise, Idaho, USA                                13
# Copenhagen, Denmark                              13
# Monterrey, Nuevo Leon, Mexico                    13
# Quebec City, Quebec, Canada                      13
# Lincoln, Nebraska, USA                           13
# Fort Campbell, Kentucky, USA                     13
# Rochester, New York, USA                         13
# Wichita, Kansas, USA                             13
# Zagreb, Croatia                                  13
# Fresno, California, USA                          13
# Tokyo, Japan                                     13
# Santiago, Chile                                  13
# Busan, South Korea                               13
# Prague, Czech Republic                           13
# Uniondale, New York, USA                         13
# Moncton, New Brunswick, Canada                   13
# Kansas City, Missouri, USA                       13
# Manila, Philippines                              12
# Shanghai, Hebei, China                           12
# Saskatoon, Saskatchewan, Canada                  12
# Hidalgo, Texas, USA                              12
# Elmont, New York, USA                            12
# Duluth, Georgia, USA                             12
# Curitiba, Parana, Brazil                         12
# Albany, New York, USA                            12
# Buenos Aires, Buenos Aires, Argentina            12
# Beijing, China                                   12
# Raleigh, North Carolina, USA                     12
# Cologne, North Rhine-Westphalia, Germany         12
# Paris, Ile-de-France, France                     12
# Utica, New York, USA                             12
# Sioux Falls, South Dakota, USA                   12
# Krakow, Poland                                   12
# Memphis, Tennessee, USA                          11
# Seoul, South Korea                               11
# Saint Petersburg, Saint Petersburg, Russia       11
# Louisville, Kentucky, USA                        11
# Belem, Para, Brazil                              11
# Natal, Rio Grande do Norte, Brazil               11
# Porto Alegre, Rio Grande do Sul, Brazil          11
# Berlin, Berlin, Germany                          11
# Auburn Hills, Michigan, USA                      11
# Killeen, Texas, USA                              11
# Gdansk, Poland                                   11
# Oakland, California, USA                         11
# Albuquerque, New Mexico, USA                     11
# St. Louis, Missouri, USA                         11
# Nottingham, England, United Kingdom              11
# Greenville, South Carolina, USA                  11
# Liverpool, England, United Kingdom               11
# Shenzhen, Guangdong, China                       11
# Uberlandia, Minas Gerais, Brazil                 10
# Baltimore, Maryland, USA                         10
# Fayetteville, North Carolina, USA                10
# Singapore, Singapore                             10
# Gold Coast, Queensland, Australia                10
# Cleveland, Ohio, USA                             10
# Oberhausen, North Rhine-Westphalia, Germany      10
# Bangor, Maine, USA                               10
# Rosemont, Illinois, USA                          10
# Saitama, Saitama, Japan                          10
# Berlin, Germany                                  10
# Ledyard, Connecticut, USA                         9
# Newcastle, England, United Kingdom                9
# San Juan, Puerto Rico                             8
# Miami, Florida, USA                               8
# Bossier City, Louisiana, USA                      8
# Mobile, Alabama, USA                              8
# Casper, Wyoming, USA                              8
# Dothan, Alabama, USA                              7
# Chiba, Japan                                      7
# Yokohama, Kanagawa, Japan                         7
# Name: location, dtype: int64

# %% [markdown]
# * Since we don't have home-country of each fighter, location is useless
# * Date of the fight is also not essential since we already created age with it
# * Draws are incredibly rare and should be removed from the target variable so it becomes a binary classification task
# * Fighter names are also to be removed

# %%
df2['Winner'].value_counts()
# Out:
# Red     4525
# Blue    2315
# Draw     125
# Name: Winner, dtype: int64

# %%
df2.drop(df2.index[df2['Winner'] == 'Draw'], inplace = True)
df2.drop(columns=['location', 'date', 'R_fighter', 'B_fighter'], inplace=True)

# %%
df2.dtypes
# Out:
# Winner                           object
# title_bout                         bool
# weight_class                     object
# no_of_rounds                      int64
# B_avg_KD                        float64
# B_avg_opp_KD                    float64
# B_avg_SIG_STR_pct               float64
# B_avg_opp_SIG_STR_pct           float64
# B_avg_TD_pct                    float64
# B_avg_opp_TD_pct                float64
# B_avg_SUB_ATT                   float64
# B_avg_opp_SUB_ATT               float64
# B_avg_REV                       float64
# B_avg_opp_REV                   float64
# B_avg_SIG_STR_att               float64
# B_avg_SIG_STR_landed            float64
# B_avg_opp_SIG_STR_att           float64
# B_avg_opp_SIG_STR_landed        float64
# B_avg_TOTAL_STR_att             float64
# B_avg_TOTAL_STR_landed          float64
# B_avg_opp_TOTAL_STR_att         float64
# B_avg_opp_TOTAL_STR_landed      float64
# B_avg_TD_att                    float64
# B_avg_TD_landed                 float64
# B_avg_opp_TD_att                float64
# B_avg_opp_TD_landed             float64
# B_avg_HEAD_att                  float64
# B_avg_HEAD_landed               float64
# B_avg_opp_HEAD_att              float64
# B_avg_opp_HEAD_landed           float64
# B_avg_BODY_att                  float64
# B_avg_BODY_landed               float64
# B_avg_opp_BODY_att              float64
# B_avg_opp_BODY_landed           float64
# B_avg_LEG_att                   float64
# B_avg_LEG_landed                float64
# B_avg_opp_LEG_att               float64
# B_avg_opp_LEG_landed            float64
# B_avg_DISTANCE_att              float64
# B_avg_DISTANCE_landed           float64
# B_avg_opp_DISTANCE_att          float64
# B_avg_opp_DISTANCE_landed       float64
# B_avg_CLINCH_att                float64
# B_avg_CLINCH_landed             float64
# B_avg_opp_CLINCH_att            float64
# B_avg_opp_CLINCH_landed         float64
# B_avg_GROUND_att                float64
# B_avg_GROUND_landed             float64
# B_avg_opp_GROUND_att            float64
# B_avg_opp_GROUND_landed         float64
# B_avg_CTRL_time(seconds)        float64
# B_avg_opp_CTRL_time(seconds)    float64
# B_total_time_fought(seconds)    float64
# B_total_rounds_fought             int64
# B_total_title_bouts               int64
# B_current_win_streak              int64
# B_current_lose_streak             int64
# B_longest_win_streak              int64
# B_wins                            int64
# B_losses                          int64
# B_draw                            int64
# B_win_by_Decision_Majority        int64
# B_win_by_Decision_Split           int64
# B_win_by_Decision_Unanimous       int64
# B_win_by_KO/TKO                   int64
# B_win_by_Submission               int64
# B_win_by_TKO_Doctor_Stoppage      int64
# B_Stance                         object
# B_Height_cms                    float64
# B_Reach_cms                     float64
# B_Weight_lbs                    float64
# R_avg_KD                        float64
# R_avg_opp_KD                    float64
# R_avg_SIG_STR_pct               float64
# R_avg_opp_SIG_STR_pct           float64
# R_avg_TD_pct                    float64
# R_avg_opp_TD_pct                float64
# R_avg_SUB_ATT                   float64
# R_avg_opp_SUB_ATT               float64
# R_avg_REV                       float64
# R_avg_opp_REV                   float64
# R_avg_SIG_STR_att               float64
# R_avg_SIG_STR_landed            float64
# R_avg_opp_SIG_STR_att           float64
# R_avg_opp_SIG_STR_landed        float64
# R_avg_TOTAL_STR_att             float64
# R_avg_TOTAL_STR_landed          float64
# R_avg_opp_TOTAL_STR_att         float64
# R_avg_opp_TOTAL_STR_landed      float64
# R_avg_TD_att                    float64
# R_avg_TD_landed                 float64
# R_avg_opp_TD_att                float64
# R_avg_opp_TD_landed             float64
# R_avg_HEAD_att                  float64
# R_avg_HEAD_landed               float64
# R_avg_opp_HEAD_att              float64
# R_avg_opp_HEAD_landed           float64
# R_avg_BODY_att                  float64
# R_avg_BODY_landed               float64
# R_avg_opp_BODY_att              float64
# R_avg_opp_BODY_landed           float64
# R_avg_LEG_att                   float64
# R_avg_LEG_landed                float64
# R_avg_opp_LEG_att               float64
# R_avg_opp_LEG_landed            float64
# R_avg_DISTANCE_att              float64
# R_avg_DISTANCE_landed           float64
# R_avg_opp_DISTANCE_att          float64
# R_avg_opp_DISTANCE_landed       float64
# R_avg_CLINCH_att                float64
# R_avg_CLINCH_landed             float64
# R_avg_opp_CLINCH_att            float64
# R_avg_opp_CLINCH_landed         float64
# R_avg_GROUND_att                float64
# R_avg_GROUND_landed             float64
# R_avg_opp_GROUND_att            float64
# R_avg_opp_GROUND_landed         float64
# R_avg_CTRL_time(seconds)        float64
# R_avg_opp_CTRL_time(seconds)    float64
# R_total_time_fought(seconds)    float64
# R_total_rounds_fought             int64
# R_total_title_bouts               int64
# R_current_win_streak              int64
# R_current_lose_streak             int64
# R_longest_win_streak              int64
# R_wins                            int64
# R_losses                          int64
# R_draw                            int64
# R_win_by_Decision_Majority        int64
# R_win_by_Decision_Split           int64
# R_win_by_Decision_Unanimous       int64
# R_win_by_KO/TKO                   int64
# R_win_by_Submission               int64
# R_win_by_TKO_Doctor_Stoppage      int64
# R_Stance                         object
# R_Height_cms                    float64
# R_Reach_cms                     float64
# R_Weight_lbs                    float64
# B_age                           float64
# R_age                           float64
# dtype: object

# %% [markdown]
# * Weight class and Stance are categories, Winner is out target variable.
# * We can one hot encode the categories

# %%
df2 = pd.concat([df2, pd.get_dummies(df2[['weight_class', 'B_Stance', 'R_Stance']])], axis=1)
df2.drop(columns=['weight_class', 'B_Stance', 'R_Stance'], inplace=True)

# %%
df2
# Out:
#      Winner  title_bout  no_of_rounds  B_avg_KD  B_avg_opp_KD  \
# 0       Red       False             3  0.570801        0.3125
# 1      Blue       False             3  0.000000        0.7500
# 2      Blue       False             3  0.000000        0.0000
# 3       Red       False             3  0.000000        0.1250
# 4       Red       False             3  0.500000        0.0000
# ...     ...         ...           ...       ...           ...
# 6961    Red       False             1  0.015625        0.0000
# 6962    Red       False             1  0.015625        0.0000
# 6963    Red       False             1  0.015625        0.0000
# 6964    Red       False             1  0.015625        0.0000
# 6965    Red       False             1  0.015625        0.0000
#
#       B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  \
# 0              0.461431               0.504418      0.035756
# 1              0.411250               0.467500      0.000000
# 2              0.560000               0.550000      0.280000
# 3              0.220625               0.515000      0.108750
# 4              0.590000               0.465000      0.000000
# ...                 ...                    ...           ...
# 6961           0.455000               0.436250      0.240000
# 6962           0.455000               0.436250      0.240000
# 6963           0.455000               0.436250      0.240000
# 6964           0.455000               0.436250      0.240000
# 6965           0.455000               0.436250      0.240000
#
#       B_avg_opp_TD_pct  B_avg_SUB_ATT  ...  B_Stance_Open Stance  \
# 0             0.143079       0.578613  ...                     0
# 1             0.000000       0.000000  ...                     0
# 2             0.000000       1.000000  ...                     0
# 3             0.250000       0.062500  ...                     0
# 4             0.500000       0.000000  ...                     0
# ...                ...            ...  ...                   ...
# 6961          0.200000       0.125000  ...                     0
# 6962          0.200000       0.125000  ...                     0
# 6963          0.200000       0.125000  ...                     0
# 6964          0.200000       0.125000  ...                     0
# 6965          0.200000       0.125000  ...                     0
#
#       B_Stance_Orthodox  B_Stance_Sideways  B_Stance_Southpaw  \
# 0                     1                  0                  0
# 1                     0                  0                  0
# 2                     1                  0                  0
# 3                     1                  0                  0
# 4                     0                  0                  1
# ...                 ...                ...                ...
# 6961                  1                  0                  0
# 6962                  1                  0                  0
# 6963                  1                  0                  0
# 6964                  1                  0                  0
# 6965                  1                  0                  0
#
#       B_Stance_Switch  R_Stance_Open Stance  R_Stance_Orthodox  \
# 0                   0                     0                  0
# 1                   1                     0                  1
# 2                   0                     0                  0
# 3                   0                     0                  0
# 4                   0                     0                  1
# ...               ...                   ...                ...
# 6961                0                     0                  0
# 6962                0                     0                  0
# 6963                0                     0                  1
# 6964                0                     0                  1
# 6965                0                     0                  1
#
#       R_Stance_Sideways  R_Stance_Southpaw  R_Stance_Switch
# 0                     0                  0                1
# 1                     0                  0                0
# 2                     0                  0                1
# 3                     0                  1                0
# 4                     0                  0                0
# ...                 ...                ...              ...
# 6961                  0                  1                0
# 6962                  0                  1                0
# 6963                  0                  0                0
# 6964                  0                  0                0
# 6965                  0                  0                0
#
# [6841 rows x 161 columns]

# %%
df2 = df2[df['Winner'].notna()]
# Out:
# <ipython-input-25-14691e14daf7>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df['Winner'].notna()]

# %% [markdown]
# ## Saving the data

# %%
df2.to_csv('../data/preprocessed_data.csv', index=False)
